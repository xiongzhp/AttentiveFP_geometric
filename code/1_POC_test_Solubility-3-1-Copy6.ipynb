# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

import time
import numpy as np
import gc
import sys
sys.setrecursionlimit(50000)
import pickle
import random
torch.set_default_tensor_type('torch.cuda.FloatTensor')
torch.nn.Module.dump_patches = True
import copy
import pandas as pd
from sklearn.model_selection import KFold

#then import my own modules
# from AttentiveFP import Fingerprint, Fingerprint_viz, save_smiles_dicts, get_smiles_dicts, get_smiles_array, moltosvg_highlight
from timeit import default_timer as timer
from AttentiveFP import Fingerprint, Fingerprint_viz, graph_dict, graph_dataset, null_collate, Graph, Logger, time_to_str

# %%
cuda_aviable = torch.cuda.is_available()
device = torch.device(0)

SEED = 8
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True
torch.backends.cudnn.deterministic=True

# %%
from rdkit import Chem
# from rdkit.Chem import AllChem
from rdkit.Chem import QED
from rdkit.Chem import rdMolDescriptors, MolSurf
from rdkit.Chem.Draw import SimilarityMaps
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
# %matplotlib inline
from numpy.polynomial.polynomial import polyfit
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib
import seaborn as sns; sns.set()
from IPython.display import SVG, display
import sascorer

# %%
task_name = 'solubility'
tasks = ['measured log solubility in mols per litre']

raw_filename = "../data/delaney-processed.csv"
feature_filename = raw_filename.replace('.csv','.pickle')
filename = raw_filename.replace('.csv','')
prefix_filename = raw_filename.split('/')[-1].replace('.csv','')
smiles_tasks_df = pd.read_csv(raw_filename)
smilesList = smiles_tasks_df.smiles.values
print("number of all smiles: ", len(smilesList))
atom_num_dist = []
remained_smiles = []
canonical_smiles_list = []
for smiles in smilesList:
    try:        
        mol = Chem.MolFromSmiles(smiles)
        atom_num_dist.append(len(mol.GetAtoms()))
        remained_smiles.append(smiles)
        canonical_smiles_list.append(Chem.MolToSmiles(Chem.MolFromSmiles(smiles), isomericSmiles=True))
    except:
        print(smiles)
        pass
print("number of successfully processed smiles: ", len(remained_smiles))

smiles_tasks_df = smiles_tasks_df[smiles_tasks_df["smiles"].isin(remained_smiles)].reset_index()
smiles_tasks_df['cano_smiles'] =canonical_smiles_list
plt.figure(figsize=(5, 3))
sns.set(font_scale=1.5)
ax = sns.distplot(atom_num_dist, bins=28, kde=False)
plt.tight_layout()
plt.show()
plt.close()
# Out:
# number of all smiles:  1128
# number of successfully processed smiles:  1128

# %%
start_time = str(time.ctime()).replace(':','-').replace(' ','_')

epochs = 80
batch_size =100

p_dropout= 0.2
fingerprint_dim = 50

weight_decay = 5 # also known as l2_regularization_lambda
learning_rate = 2.5
K = 2
T = 2
per_task_output_units_num = 1 # for regression model
output_units_num = len(tasks) * per_task_output_units_num

# %%
smiles_list = smiles_tasks_df['smiles'].values
label_list = smiles_tasks_df[tasks[0]].values
graph_dict = graph_dict(smiles_list, label_list, filename)
# Out:
# graph dicts loaded from ../data/delaney-processed.pkl

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
train_fold = []
valid_fold = []
for k, (train_idx, valid_idx) in enumerate(kfold.split(smiles_list)):
    train_fold.append(train_idx)
    valid_fold.append(valid_idx)
    
# avoiding the last batch has too few samples by slightly tune the batch_size
while (len(train_fold[0]) % batch_size) / batch_size <0.8:
    batch_size +=1
print("batch size: ", batch_size)
# Out:
# batch size:  101

# %%
loss_function = nn.MSELoss()
model = Fingerprint(output_units_num, fingerprint_dim, K=K, T=T, p_dropout=p_dropout)
model.to(device)

# optimizer = optim.Adam(model.parameters(), learning_rate, weight_decay=weight_decay)
optimizer = optim.Adam(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)
# optimizer = optim.SGD(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)

# model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in  model.parameters()])
print(params)
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data.shape)
# Out:
# 166954
# sum_importance torch.Size([1])
# preprocess.0.linear.weight torch.Size([50, 39])
# preprocess.0.linear.bias torch.Size([50])
# preprocess.0.bn.weight torch.Size([50])
# preprocess.0.bn.bias torch.Size([50])
# propagate.0.encoder.0.linear.weight torch.Size([2500, 10])
# propagate.0.encoder.0.linear.bias torch.Size([2500])
# propagate.0.encoder.0.bn.weight torch.Size([2500])
# propagate.0.encoder.0.bn.bias torch.Size([2500])
# propagate.0.align.weight torch.Size([1, 100])
# propagate.0.align.bias torch.Size([1])
# propagate.0.attend.linear.weight torch.Size([50, 50])
# propagate.0.attend.linear.bias torch.Size([50])
# propagate.0.attend.bn.weight torch.Size([50])
# propagate.0.attend.bn.bias torch.Size([50])
# propagate.0.gru.weight_ih torch.Size([150, 50])
# propagate.0.gru.weight_hh torch.Size([150, 50])
# propagate.0.gru.bias_ih torch.Size([150])
# propagate.0.gru.bias_hh torch.Size([150])
# propagate.1.encoder.0.linear.weight torch.Size([2500, 10])
# propagate.1.encoder.0.linear.bias torch.Size([2500])
# propagate.1.encoder.0.bn.weight torch.Size([2500])
# propagate.1.encoder.0.bn.bias torch.Size([2500])
# propagate.1.align.weight torch.Size([1, 100])
# propagate.1.align.bias torch.Size([1])
# propagate.1.attend.linear.weight torch.Size([50, 50])
# propagate.1.attend.linear.bias torch.Size([50])
# propagate.1.attend.bn.weight torch.Size([50])
# propagate.1.attend.bn.bias torch.Size([50])
# propagate.1.gru.weight_ih torch.Size([150, 50])
# propagate.1.gru.weight_hh torch.Size([150, 50])
# propagate.1.gru.bias_ih torch.Size([150])
# propagate.1.gru.bias_hh torch.Size([150])
# superGather.0.align.weight torch.Size([1, 100])
# superGather.0.align.bias torch.Size([1])
# superGather.0.attend.linear.weight torch.Size([50, 50])
# superGather.0.attend.linear.bias torch.Size([50])
# superGather.0.attend.bn.weight torch.Size([50])
# superGather.0.attend.bn.bias torch.Size([50])
# superGather.0.gru.weight_ih torch.Size([150, 50])
# superGather.0.gru.weight_hh torch.Size([150, 50])
# superGather.0.gru.bias_ih torch.Size([150])
# superGather.0.gru.bias_hh torch.Size([150])
# superGather.1.align.weight torch.Size([1, 100])
# superGather.1.align.bias torch.Size([1])
# superGather.1.attend.linear.weight torch.Size([50, 50])
# superGather.1.attend.linear.bias torch.Size([50])
# superGather.1.attend.bn.weight torch.Size([50])
# superGather.1.attend.bn.bias torch.Size([50])
# superGather.1.gru.weight_ih torch.Size([150, 50])
# superGather.1.gru.weight_hh torch.Size([150, 50])
# superGather.1.gru.bias_ih torch.Size([150])
# superGather.1.gru.bias_hh torch.Size([150])
# predict.0.linear.weight torch.Size([512, 50])
# predict.0.linear.bias torch.Size([512])
# predict.0.bn.weight torch.Size([512])
# predict.0.bn.bias torch.Size([512])
# predict.3.weight torch.Size([1, 512])
# predict.3.bias torch.Size([1])

# %%
def train(smiles_list):
    model.train()
    train_loader = DataLoader(graph_dataset(smiles_list, graph_dict), batch_size, collate_fn=null_collate, \
                              num_workers=8, pin_memory=True, shuffle=True, worker_init_fn=np.random.seed(SEED))
    losses = []
    for b, (smiles, atom, bond, bond_index, mol_index, label) in enumerate(train_loader):
        atom = atom.to(device)
        bond = bond.to(device)
        bond_index = bond_index.to(device)
        mol_index = mol_index.to(device)
        label = label.to(device)
        
        mol_prediction = model(atom, bond, bond_index, mol_index)
        
        loss = loss_function(mol_prediction, label.view(-1,1))     
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        losses.append(loss.item())

    return np.mean(losses)

        
def eval(smiles_list):
    model.eval()
    eval_MAE_list = []
    eval_MSE_list = []
    eval_loader = DataLoader(graph_dataset(smiles_list, graph_dict), batch_size, collate_fn=null_collate, \
                              num_workers=8, pin_memory=True, shuffle=False, worker_init_fn=np.random.seed(SEED))
    for b, (smiles, atom, bond, bond_index, mol_index, label) in enumerate(eval_loader):
        atom = atom.to(device)
        bond = bond.to(device)
        bond_index = bond_index.to(device)
        mol_index = mol_index.to(device)
        label = label.to(device)
        
        mol_prediction = model(atom, bond, bond_index, mol_index)
        MAE = F.l1_loss(mol_prediction, label.view(-1,1), reduction='none')        
        MSE = F.mse_loss(mol_prediction, label.view(-1,1), reduction='none')
        
        eval_MAE_list.extend(MAE.data.squeeze().cpu().numpy())
        eval_MSE_list.extend(MSE.data.squeeze().cpu().numpy())
    return np.array(eval_MAE_list).mean(), np.array(eval_MSE_list).mean()

# %%
# log = Logger()
# log.open(f'{prefix_filename}_{start_time}.txt')

# f = '{:^5} | {:^7.4f} | {:^7.4f} | {:^7.4f} | {:^7} \n'
# log.write('epoch | loss | train MSE |  valid MSE |  time \n')
# start = timer()

# best_param ={}
# best_param["train_epoch"] = 0
# best_param["valid_epoch"] = 0
# best_param["train_MSE"] = 9e8
# best_param["valid_MSE"] = 9e8

# fold_index = 3
# for epoch in range(800):
#     losses = train(smiles_list[train_fold[fold_index]])
#     traine_MAE, train_MSE = eval(smiles_list[train_fold[fold_index]])
#     valid_MAE, valid_MSE = eval(smiles_list[valid_fold[fold_index]])

#     timing = time_to_str((timer() - start), 'min')  
#     log.write(f.format(epoch, losses, train_MSE, valid_MSE, timing))

#     if train_MSE < best_param["train_MSE"]:
#         best_param["train_epoch"] = epoch
#         best_param["train_MSE"] = train_MSE
#     if valid_MSE < best_param["valid_MSE"]:
#         best_param["valid_epoch"] = epoch
#         best_param["valid_MSE"] = valid_MSE
# #         if valid_MSE < 0.35:
# #              torch.save(model, 'saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(epoch)+'.pt')
#     if (epoch - best_param["train_epoch"] >10) and (epoch - best_param["valid_epoch"] >18):        
#         break
# print(best_param["valid_epoch"],best_param["train_MSE"],best_param["valid_MSE"])

# %%
log = Logger()
log.open(f'log/{prefix_filename}_{start_time}.txt')

f = '{:^5} | {:^7.4f} | {:^7.4f} | {:^7.4f} | {:^7} \n'
log.write('epoch | loss | train MSE |  valid MSE |  time \n')
start = timer()

log2 = Logger()
log2.open(f'{prefix_filename}_best_{start_time}.txt')
f2 = '{:^5} | {:^5} | {:^7.4f} | {:^7.4f} \n'

for fold_index in range(5):
    
    model = Fingerprint(output_units_num, fingerprint_dim, K=K, T=T, p_dropout=p_dropout)
    model.to(device)

    optimizer = optim.Adam(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)
    
    best_param ={}
    best_param["train_epoch"] = 0
    best_param["valid_epoch"] = 0
    best_param["train_MSE"] = 800
    best_param["valid_MSE"] = 800
    for epoch in range(800):
        losses = train(smiles_list[train_fold[fold_index]])
        traine_MAE, train_MSE = eval(smiles_list[train_fold[fold_index]])
        valid_MAE, valid_MSE = eval(smiles_list[valid_fold[fold_index]])
        
        timing = time_to_str((timer() - start), 'min')  
        log.write(f.format(epoch, losses, train_MSE, valid_MSE, timing))
        
        if train_MSE < best_param["train_MSE"]:
            best_param["train_epoch"] = epoch
            best_param["train_MSE"] = train_MSE
        if valid_MSE < best_param["valid_MSE"]:
            best_param["valid_epoch"] = epoch
            best_param["valid_MSE"] = valid_MSE
#             if valid_MSE < 0.35:
#                  torch.save(model, 'saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(epoch)+'.pt')
        if (epoch - best_param["train_epoch"] >10) and (epoch - best_param["valid_epoch"] >18):        
            break

    log2.write('fold | epoch | train_MSE | valid MSE \n')
    log2.write(f2.format(fold_index, best_param["valid_epoch"],best_param["train_MSE"],best_param["valid_MSE"]))
# Out:
# epoch | loss | train MSE |  valid MSE |  time
# Parameter containing:
# tensor([0.5000], requires_grad=True)
# Parameter containing:
# tensor([0.4968], requires_grad=True)
# Parameter containing:
# tensor([0.4959], requires_grad=True)
# Parameter containing:
# tensor([0.4955], requires_grad=True)
# Parameter containing:
# tensor([0.4959], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4935], requires_grad=True)
# Parameter containing:
# tensor([0.4915], requires_grad=True)
# Parameter containing:
# tensor([0.4905], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
#   0   | 5.5015  | 5.7286  | 6.0160  |  0 hr 00 min
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4907], requires_grad=True)
# Parameter containing:
# tensor([0.4918], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4940], requires_grad=True)
# Parameter containing:
# tensor([0.4942], requires_grad=True)
# Parameter containing:
# tensor([0.4943], requires_grad=True)
# Parameter containing:
# tensor([0.4948], requires_grad=True)
# Parameter containing:
# tensor([0.4955], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
#   1   | 1.8794  | 2.4425  | 3.0655  |  0 hr 00 min
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4969], requires_grad=True)
# Parameter containing:
# tensor([0.4978], requires_grad=True)
# Parameter containing:
# tensor([0.4985], requires_grad=True)
# Parameter containing:
# tensor([0.4991], requires_grad=True)
# Parameter containing:
# tensor([0.4996], requires_grad=True)
# Parameter containing:
# tensor([0.5004], requires_grad=True)
# Parameter containing:
# tensor([0.5015], requires_grad=True)
# Parameter containing:
# tensor([0.5022], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
#   2   | 1.1235  | 2.5283  | 3.1585  |  0 hr 00 min
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5010], requires_grad=True)
# Parameter containing:
# tensor([0.5001], requires_grad=True)
# Parameter containing:
# tensor([0.4994], requires_grad=True)
# Parameter containing:
# tensor([0.4985], requires_grad=True)
# Parameter containing:
# tensor([0.4976], requires_grad=True)
# Parameter containing:
# tensor([0.4967], requires_grad=True)
# Parameter containing:
# tensor([0.4959], requires_grad=True)
# Parameter containing:
# tensor([0.4956], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4953], requires_grad=True)
#   3   | 0.8471  | 2.4750  | 2.9323  |  0 hr 00 min
# Parameter containing:
# tensor([0.4953], requires_grad=True)
# Parameter containing:
# tensor([0.4951], requires_grad=True)
# Parameter containing:
# tensor([0.4949], requires_grad=True)
# Parameter containing:
# tensor([0.4946], requires_grad=True)
# Parameter containing:
# tensor([0.4945], requires_grad=True)
# Parameter containing:
# tensor([0.4942], requires_grad=True)
# Parameter containing:
# tensor([0.4938], requires_grad=True)
# Parameter containing:
# tensor([0.4936], requires_grad=True)
# Parameter containing:
# tensor([0.4934], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
#   4   | 0.6021  | 1.0376  | 1.1161  |  0 hr 00 min
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4930], requires_grad=True)
# Parameter containing:
# tensor([0.4928], requires_grad=True)
# Parameter containing:
# tensor([0.4930], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4934], requires_grad=True)
# Parameter containing:
# tensor([0.4936], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
#   5   | 0.5730  | 0.5338  | 0.5971  |  0 hr 00 min
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4934], requires_grad=True)
# Parameter containing:
# tensor([0.4930], requires_grad=True)
# Parameter containing:
# tensor([0.4924], requires_grad=True)
# Parameter containing:
# tensor([0.4918], requires_grad=True)
# Parameter containing:
# tensor([0.4917], requires_grad=True)
# Parameter containing:
# tensor([0.4916], requires_grad=True)
# Parameter containing:
# tensor([0.4920], requires_grad=True)
# Parameter containing:
# tensor([0.4925], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
#   6   | 0.5659  | 0.5253  | 0.6143  |  0 hr 00 min
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4935], requires_grad=True)
# Parameter containing:
# tensor([0.4938], requires_grad=True)
# Parameter containing:
# tensor([0.4936], requires_grad=True)
# Parameter containing:
# tensor([0.4931], requires_grad=True)
# Parameter containing:
# tensor([0.4926], requires_grad=True)
# Parameter containing:
# tensor([0.4920], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4910], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4909], requires_grad=True)
#   7   | 0.5893  | 0.3928  | 0.4949  |  0 hr 00 min
# Parameter containing:
# tensor([0.4909], requires_grad=True)
# Parameter containing:
# tensor([0.4905], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4902], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4905], requires_grad=True)
# Parameter containing:
# tensor([0.4905], requires_grad=True)
# Parameter containing:
# tensor([0.4906], requires_grad=True)
# Parameter containing:
# tensor([0.4906], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
#   8   | 0.4446  | 0.3423  | 0.4969  |  0 hr 00 min
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4899], requires_grad=True)
# Parameter containing:
# tensor([0.4897], requires_grad=True)
# Parameter containing:
# tensor([0.4892], requires_grad=True)
# Parameter containing:
# tensor([0.4888], requires_grad=True)
# Parameter containing:
# tensor([0.4885], requires_grad=True)
# Parameter containing:
# tensor([0.4886], requires_grad=True)
# Parameter containing:
# tensor([0.4891], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4896], requires_grad=True)
#   9   | 0.4331  | 0.2965  | 0.4038  |  0 hr 00 min
# Parameter containing:
# tensor([0.4896], requires_grad=True)
# Parameter containing:
# tensor([0.4900], requires_grad=True)
# Parameter containing:
# tensor([0.4901], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4904], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4902], requires_grad=True)
# Parameter containing:
# tensor([0.4900], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4903], requires_grad=True)
#  10   | 0.4151  | 0.2862  | 0.4445  |  0 hr 00 min
# Parameter containing:
# tensor([0.4903], requires_grad=True)
# Parameter containing:
# tensor([0.4908], requires_grad=True)
# Parameter containing:
# tensor([0.4915], requires_grad=True)
# Parameter containing:
# tensor([0.4919], requires_grad=True)
# Parameter containing:
# tensor([0.4922], requires_grad=True)
# Parameter containing:
# tensor([0.4925], requires_grad=True)
# Parameter containing:
# tensor([0.4924], requires_grad=True)
# Parameter containing:
# tensor([0.4920], requires_grad=True)
# Parameter containing:
# tensor([0.4915], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
#  11   | 0.4169  | 0.3064  | 0.4661  |  0 hr 00 min
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4914], requires_grad=True)
# Parameter containing:
# tensor([0.4917], requires_grad=True)
# Parameter containing:
# tensor([0.4920], requires_grad=True)
# Parameter containing:
# tensor([0.4921], requires_grad=True)
# Parameter containing:
# tensor([0.4922], requires_grad=True)
# Parameter containing:
# tensor([0.4922], requires_grad=True)
# Parameter containing:
# tensor([0.4921], requires_grad=True)
# Parameter containing:
# tensor([0.4920], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4923], requires_grad=True)
#  12   | 0.4665  | 0.2418  | 0.3871  |  0 hr 00 min
# Parameter containing:
# tensor([0.4923], requires_grad=True)
# Parameter containing:
# tensor([0.4925], requires_grad=True)
# Parameter containing:
# tensor([0.4928], requires_grad=True)
# Parameter containing:
# tensor([0.4932], requires_grad=True)
# Parameter containing:
# tensor([0.4937], requires_grad=True)
# Parameter containing:
# tensor([0.4945], requires_grad=True)
# Parameter containing:
# tensor([0.4954], requires_grad=True)
# Parameter containing:
# tensor([0.4962], requires_grad=True)
# Parameter containing:
# tensor([0.4969], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
#  13   | 0.4008  | 0.3460  | 0.4517  |  0 hr 00 min
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4972], requires_grad=True)
# Parameter containing:
# tensor([0.4968], requires_grad=True)
# Parameter containing:
# tensor([0.4962], requires_grad=True)
# Parameter containing:
# tensor([0.4954], requires_grad=True)
# Parameter containing:
# tensor([0.4947], requires_grad=True)
# Parameter containing:
# tensor([0.4943], requires_grad=True)
# Parameter containing:
# tensor([0.4946], requires_grad=True)
# Parameter containing:
# tensor([0.4949], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4952], requires_grad=True)
#  14   | 0.3846  | 0.2288  | 0.4079  |  0 hr 00 min
# Parameter containing:
# tensor([0.4952], requires_grad=True)
# Parameter containing:
# tensor([0.4956], requires_grad=True)
# Parameter containing:
# tensor([0.4959], requires_grad=True)
# Parameter containing:
# tensor([0.4963], requires_grad=True)
# Parameter containing:
# tensor([0.4967], requires_grad=True)
# Parameter containing:
# tensor([0.4969], requires_grad=True)
# Parameter containing:
# tensor([0.4970], requires_grad=True)
# Parameter containing:
# tensor([0.4970], requires_grad=True)
# Parameter containing:
# tensor([0.4970], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4964], requires_grad=True)
#  15   | 0.3337  | 0.1974  | 0.3688  |  0 hr 00 min
# Parameter containing:
# tensor([0.4964], requires_grad=True)
# Parameter containing:
# tensor([0.4961], requires_grad=True)
# Parameter containing:
# tensor([0.4959], requires_grad=True)
# Parameter containing:
# tensor([0.4956], requires_grad=True)
# Parameter containing:
# tensor([0.4955], requires_grad=True)
# Parameter containing:
# tensor([0.4955], requires_grad=True)
# Parameter containing:
# tensor([0.4957], requires_grad=True)
# Parameter containing:
# tensor([0.4962], requires_grad=True)
# Parameter containing:
# tensor([0.4971], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4979], requires_grad=True)
#  16   | 0.3699  | 0.2301  | 0.4303  |  0 hr 00 min
# Parameter containing:
# tensor([0.4979], requires_grad=True)
# Parameter containing:
# tensor([0.4987], requires_grad=True)
# Parameter containing:
# tensor([0.4994], requires_grad=True)
# Parameter containing:
# tensor([0.4998], requires_grad=True)
# Parameter containing:
# tensor([0.5000], requires_grad=True)
# Parameter containing:
# tensor([0.5001], requires_grad=True)
# Parameter containing:
# tensor([0.5001], requires_grad=True)
# Parameter containing:
# tensor([0.5000], requires_grad=True)
# Parameter containing:
# tensor([0.5004], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5009], requires_grad=True)
#  17   | 0.3468  | 0.3150  | 0.4910  |  0 hr 00 min
# Parameter containing:
# tensor([0.5009], requires_grad=True)
# Parameter containing:
# tensor([0.5012], requires_grad=True)
# Parameter containing:
# tensor([0.5016], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5017], requires_grad=True)
# Parameter containing:
# tensor([0.5017], requires_grad=True)
# Parameter containing:
# tensor([0.5017], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
#  18   | 0.3690  | 0.1829  | 0.4077  |  0 hr 00 min
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5018], requires_grad=True)
# Parameter containing:
# tensor([0.5022], requires_grad=True)
# Parameter containing:
# tensor([0.5026], requires_grad=True)
# Parameter containing:
# tensor([0.5028], requires_grad=True)
# Parameter containing:
# tensor([0.5031], requires_grad=True)
# Parameter containing:
# tensor([0.5034], requires_grad=True)
# Parameter containing:
# tensor([0.5038], requires_grad=True)
# Parameter containing:
# tensor([0.5042], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5044], requires_grad=True)
#  19   | 0.2729  | 0.1880  | 0.3575  |  0 hr 00 min
# Parameter containing:
# tensor([0.5044], requires_grad=True)
# Parameter containing:
# tensor([0.5045], requires_grad=True)
# Parameter containing:
# tensor([0.5046], requires_grad=True)
# Parameter containing:
# tensor([0.5050], requires_grad=True)
# Parameter containing:
# tensor([0.5054], requires_grad=True)
# Parameter containing:
# tensor([0.5060], requires_grad=True)
# Parameter containing:
# tensor([0.5064], requires_grad=True)
# Parameter containing:
# tensor([0.5069], requires_grad=True)
# Parameter containing:
# tensor([0.5070], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
#  20   | 0.3653  | 0.2310  | 0.4476  |  0 hr 00 min
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5063], requires_grad=True)
# Parameter containing:
# tensor([0.5063], requires_grad=True)
# Parameter containing:
# tensor([0.5061], requires_grad=True)
# Parameter containing:
# tensor([0.5063], requires_grad=True)
# Parameter containing:
# tensor([0.5066], requires_grad=True)
# Parameter containing:
# tensor([0.5070], requires_grad=True)
# Parameter containing:
# tensor([0.5072], requires_grad=True)
# Parameter containing:
# tensor([0.5076], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5079], requires_grad=True)
#  21   | 0.4034  | 0.2626  | 0.4885  |  0 hr 00 min
# Parameter containing:
# tensor([0.5079], requires_grad=True)
# Parameter containing:
# tensor([0.5084], requires_grad=True)
# Parameter containing:
# tensor([0.5088], requires_grad=True)
# Parameter containing:
# tensor([0.5090], requires_grad=True)
# Parameter containing:
# tensor([0.5090], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5090], requires_grad=True)
# Parameter containing:
# tensor([0.5086], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5080], requires_grad=True)
#  22   | 0.3415  | 0.2330  | 0.4259  |  0 hr 00 min
# Parameter containing:
# tensor([0.5080], requires_grad=True)
# Parameter containing:
# tensor([0.5071], requires_grad=True)
# Parameter containing:
# tensor([0.5068], requires_grad=True)
# Parameter containing:
# tensor([0.5067], requires_grad=True)
# Parameter containing:
# tensor([0.5069], requires_grad=True)
# Parameter containing:
# tensor([0.5073], requires_grad=True)
# Parameter containing:
# tensor([0.5078], requires_grad=True)
# Parameter containing:
# tensor([0.5083], requires_grad=True)
# Parameter containing:
# tensor([0.5086], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
#  23   | 0.3257  | 0.2232  | 0.3967  |  0 hr 00 min
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5092], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5099], requires_grad=True)
# Parameter containing:
# tensor([0.5095], requires_grad=True)
# Parameter containing:
# tensor([0.5092], requires_grad=True)
# Parameter containing:
# tensor([0.5089], requires_grad=True)
# Parameter containing:
# tensor([0.5088], requires_grad=True)
# Parameter containing:
# tensor([0.5092], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5097], requires_grad=True)
#  24   | 0.3137  | 0.2073  | 0.4393  |  0 hr 00 min
# Parameter containing:
# tensor([0.5097], requires_grad=True)
# Parameter containing:
# tensor([0.5105], requires_grad=True)
# Parameter containing:
# tensor([0.5108], requires_grad=True)
# Parameter containing:
# tensor([0.5110], requires_grad=True)
# Parameter containing:
# tensor([0.5110], requires_grad=True)
# Parameter containing:
# tensor([0.5110], requires_grad=True)
# Parameter containing:
# tensor([0.5109], requires_grad=True)
# Parameter containing:
# tensor([0.5108], requires_grad=True)
# Parameter containing:
# tensor([0.5108], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
#  25   | 0.3609  | 0.2838  | 0.4372  |  0 hr 00 min
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5112], requires_grad=True)
# Parameter containing:
# tensor([0.5116], requires_grad=True)
# Parameter containing:
# tensor([0.5120], requires_grad=True)
# Parameter containing:
# tensor([0.5122], requires_grad=True)
# Parameter containing:
# tensor([0.5126], requires_grad=True)
# Parameter containing:
# tensor([0.5129], requires_grad=True)
# Parameter containing:
# tensor([0.5133], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
#  26   | 0.3251  | 0.2298  | 0.4422  |  0 hr 00 min
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5139], requires_grad=True)
# Parameter containing:
# tensor([0.5139], requires_grad=True)
# Parameter containing:
# tensor([0.5139], requires_grad=True)
# Parameter containing:
# tensor([0.5139], requires_grad=True)
# Parameter containing:
# tensor([0.5137], requires_grad=True)
# Parameter containing:
# tensor([0.5131], requires_grad=True)
# Parameter containing:
# tensor([0.5122], requires_grad=True)
# Parameter containing:
# tensor([0.5114], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5107], requires_grad=True)
#  27   | 0.3028  | 0.2475  | 0.4742  |  0 hr 00 min
# Parameter containing:
# tensor([0.5107], requires_grad=True)
# Parameter containing:
# tensor([0.5103], requires_grad=True)
# Parameter containing:
# tensor([0.5100], requires_grad=True)
# Parameter containing:
# tensor([0.5103], requires_grad=True)
# Parameter containing:
# tensor([0.5106], requires_grad=True)
# Parameter containing:
# tensor([0.5114], requires_grad=True)
# Parameter containing:
# tensor([0.5118], requires_grad=True)
# Parameter containing:
# tensor([0.5123], requires_grad=True)
# Parameter containing:
# tensor([0.5130], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5135], requires_grad=True)
#  28   | 0.3487  | 0.2856  | 0.4546  |  0 hr 00 min
# Parameter containing:
# tensor([0.5135], requires_grad=True)
# Parameter containing:
# tensor([0.5141], requires_grad=True)
# Parameter containing:
# tensor([0.5145], requires_grad=True)
# Parameter containing:
# tensor([0.5146], requires_grad=True)
# Parameter containing:
# tensor([0.5146], requires_grad=True)
# Parameter containing:
# tensor([0.5145], requires_grad=True)
# Parameter containing:
# tensor([0.5146], requires_grad=True)
# Parameter containing:
# tensor([0.5140], requires_grad=True)
# Parameter containing:
# tensor([0.5132], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5127], requires_grad=True)
#  29   | 0.3902  | 0.2443  | 0.3809  |  0 hr 00 min
# Parameter containing:
# tensor([0.5127], requires_grad=True)
# Parameter containing:
# tensor([0.5123], requires_grad=True)
# Parameter containing:
# tensor([0.5126], requires_grad=True)
# Parameter containing:
# tensor([0.5132], requires_grad=True)
# Parameter containing:
# tensor([0.5140], requires_grad=True)
# Parameter containing:
# tensor([0.5147], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5155], requires_grad=True)
# Parameter containing:
# tensor([0.5155], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
#  30   | 0.2909  | 0.1858  | 0.3829  |  0 hr 00 min
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5149], requires_grad=True)
# Parameter containing:
# tensor([0.5146], requires_grad=True)
# Parameter containing:
# tensor([0.5148], requires_grad=True)
# Parameter containing:
# tensor([0.5153], requires_grad=True)
# Parameter containing:
# tensor([0.5158], requires_grad=True)
# Parameter containing:
# tensor([0.5163], requires_grad=True)
# Parameter containing:
# tensor([0.5167], requires_grad=True)
# Parameter containing:
# tensor([0.5171], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
#  31   | 0.2564  | 0.2713  | 0.4681  |  0 hr 01 min
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5177], requires_grad=True)
# Parameter containing:
# tensor([0.5179], requires_grad=True)
# Parameter containing:
# tensor([0.5180], requires_grad=True)
# Parameter containing:
# tensor([0.5176], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5171], requires_grad=True)
# Parameter containing:
# tensor([0.5171], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
#  32   | 0.2594  | 0.1638  | 0.4142  |  0 hr 01 min
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5176], requires_grad=True)
# Parameter containing:
# tensor([0.5178], requires_grad=True)
# Parameter containing:
# tensor([0.5179], requires_grad=True)
# Parameter containing:
# tensor([0.5178], requires_grad=True)
# Parameter containing:
# tensor([0.5176], requires_grad=True)
# Parameter containing:
# tensor([0.5174], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5173], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5175], requires_grad=True)
#  33   | 0.3382  | 0.1454  | 0.4106  |  0 hr 01 min
# Parameter containing:
# tensor([0.5175], requires_grad=True)
# Parameter containing:
# tensor([0.5178], requires_grad=True)
# Parameter containing:
# tensor([0.5180], requires_grad=True)
# Parameter containing:
# tensor([0.5181], requires_grad=True)
# Parameter containing:
# tensor([0.5181], requires_grad=True)
# Parameter containing:
# tensor([0.5182], requires_grad=True)
# Parameter containing:
# tensor([0.5184], requires_grad=True)
# Parameter containing:
# tensor([0.5188], requires_grad=True)
# Parameter containing:
# tensor([0.5192], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
#  34   | 0.2860  | 0.1486  | 0.4094  |  0 hr 01 min
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5196], requires_grad=True)
# Parameter containing:
# tensor([0.5198], requires_grad=True)
# Parameter containing:
# tensor([0.5196], requires_grad=True)
# Parameter containing:
# tensor([0.5197], requires_grad=True)
# Parameter containing:
# tensor([0.5195], requires_grad=True)
# Parameter containing:
# tensor([0.5193], requires_grad=True)
# Parameter containing:
# tensor([0.5193], requires_grad=True)
# Parameter containing:
# tensor([0.5191], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
#  35   | 0.2630  | 0.1328  | 0.3826  |  0 hr 01 min
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5187], requires_grad=True)
# Parameter containing:
# tensor([0.5188], requires_grad=True)
# Parameter containing:
# tensor([0.5190], requires_grad=True)
# Parameter containing:
# tensor([0.5196], requires_grad=True)
# Parameter containing:
# tensor([0.5203], requires_grad=True)
# Parameter containing:
# tensor([0.5213], requires_grad=True)
# Parameter containing:
# tensor([0.5221], requires_grad=True)
# Parameter containing:
# tensor([0.5228], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5232], requires_grad=True)
#  36   | 0.2480  | 0.1396  | 0.3885  |  0 hr 01 min
# Parameter containing:
# tensor([0.5232], requires_grad=True)
# Parameter containing:
# tensor([0.5233], requires_grad=True)
# Parameter containing:
# tensor([0.5234], requires_grad=True)
# ...
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
#  79   | 0.2035  | 0.0767  | 0.4282  |  0 hr 13 min
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5603], requires_grad=True)
# Parameter containing:
# tensor([0.5603], requires_grad=True)
# Parameter containing:
# tensor([0.5604], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5595], requires_grad=True)
# Parameter containing:
# tensor([0.5588], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
#  80   | 0.1356  | 0.0622  | 0.4358  |  0 hr 13 min
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5588], requires_grad=True)
# Parameter containing:
# tensor([0.5595], requires_grad=True)
# Parameter containing:
# tensor([0.5602], requires_grad=True)
# Parameter containing:
# tensor([0.5607], requires_grad=True)
# Parameter containing:
# tensor([0.5606], requires_grad=True)
# Parameter containing:
# tensor([0.5604], requires_grad=True)
# Parameter containing:
# tensor([0.5599], requires_grad=True)
# Parameter containing:
# tensor([0.5591], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5582], requires_grad=True)
#  81   | 0.1910  | 0.0724  | 0.3997  |  0 hr 13 min
# Parameter containing:
# tensor([0.5582], requires_grad=True)
# Parameter containing:
# tensor([0.5574], requires_grad=True)
# Parameter containing:
# tensor([0.5567], requires_grad=True)
# Parameter containing:
# tensor([0.5562], requires_grad=True)
# Parameter containing:
# tensor([0.5561], requires_grad=True)
# Parameter containing:
# tensor([0.5560], requires_grad=True)
# Parameter containing:
# tensor([0.5561], requires_grad=True)
# Parameter containing:
# tensor([0.5562], requires_grad=True)
# Parameter containing:
# tensor([0.5563], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5568], requires_grad=True)
#  82   | 0.2301  | 0.1265  | 0.5073  |  0 hr 13 min
# Parameter containing:
# tensor([0.5568], requires_grad=True)
# Parameter containing:
# tensor([0.5569], requires_grad=True)
# Parameter containing:
# tensor([0.5571], requires_grad=True)
# Parameter containing:
# tensor([0.5571], requires_grad=True)
# Parameter containing:
# tensor([0.5569], requires_grad=True)
# Parameter containing:
# tensor([0.5567], requires_grad=True)
# Parameter containing:
# tensor([0.5566], requires_grad=True)
# Parameter containing:
# tensor([0.5567], requires_grad=True)
# Parameter containing:
# tensor([0.5569], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5573], requires_grad=True)
#  83   | 0.2102  | 0.0921  | 0.4786  |  0 hr 13 min
# Parameter containing:
# tensor([0.5573], requires_grad=True)
# Parameter containing:
# tensor([0.5579], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5589], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5606], requires_grad=True)
# Parameter containing:
# tensor([0.5612], requires_grad=True)
# Parameter containing:
# tensor([0.5618], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
#  84   | 0.1811  | 0.0887  | 0.4689  |  0 hr 13 min
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5621], requires_grad=True)
# Parameter containing:
# tensor([0.5619], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5612], requires_grad=True)
# Parameter containing:
# tensor([0.5606], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5594], requires_grad=True)
# Parameter containing:
# tensor([0.5594], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5600], requires_grad=True)
#  85   | 0.2018  | 0.0681  | 0.4076  |  0 hr 13 min
# Parameter containing:
# tensor([0.5600], requires_grad=True)
# Parameter containing:
# tensor([0.5607], requires_grad=True)
# Parameter containing:
# tensor([0.5610], requires_grad=True)
# Parameter containing:
# tensor([0.5613], requires_grad=True)
# Parameter containing:
# tensor([0.5616], requires_grad=True)
# Parameter containing:
# tensor([0.5618], requires_grad=True)
# Parameter containing:
# tensor([0.5618], requires_grad=True)
# Parameter containing:
# tensor([0.5619], requires_grad=True)
# Parameter containing:
# tensor([0.5619], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
#  86   | 0.1411  | 0.0667  | 0.4226  |  0 hr 13 min
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5615], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5612], requires_grad=True)
# Parameter containing:
# tensor([0.5615], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5620], requires_grad=True)
# Parameter containing:
# tensor([0.5620], requires_grad=True)
# Parameter containing:
# tensor([0.5619], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
#  87   | 0.1384  | 0.0677  | 0.4425  |  0 hr 13 min
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5617], requires_grad=True)
# Parameter containing:
# tensor([0.5616], requires_grad=True)
# Parameter containing:
# tensor([0.5616], requires_grad=True)
# Parameter containing:
# tensor([0.5613], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5607], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5611], requires_grad=True)
#  88   | 0.1631  | 0.0776  | 0.4259  |  0 hr 13 min
# Parameter containing:
# tensor([0.5611], requires_grad=True)
# Parameter containing:
# tensor([0.5612], requires_grad=True)
# Parameter containing:
# tensor([0.5614], requires_grad=True)
# Parameter containing:
# tensor([0.5614], requires_grad=True)
# Parameter containing:
# tensor([0.5613], requires_grad=True)
# Parameter containing:
# tensor([0.5614], requires_grad=True)
# Parameter containing:
# tensor([0.5615], requires_grad=True)
# Parameter containing:
# tensor([0.5615], requires_grad=True)
# Parameter containing:
# tensor([0.5613], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5609], requires_grad=True)
#  89   | 0.1807  | 0.1093  | 0.4671  |  0 hr 13 min
# Parameter containing:
# tensor([0.5609], requires_grad=True)
# Parameter containing:
# tensor([0.5603], requires_grad=True)
# Parameter containing:
# tensor([0.5598], requires_grad=True)
# Parameter containing:
# tensor([0.5594], requires_grad=True)
# Parameter containing:
# tensor([0.5589], requires_grad=True)
# Parameter containing:
# tensor([0.5587], requires_grad=True)
# Parameter containing:
# tensor([0.5587], requires_grad=True)
# Parameter containing:
# tensor([0.5589], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
#  90   | 0.1524  | 0.0753  | 0.4444  |  0 hr 13 min
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5587], requires_grad=True)
# Parameter containing:
# tensor([0.5588], requires_grad=True)
# Parameter containing:
# tensor([0.5588], requires_grad=True)
# Parameter containing:
# tensor([0.5587], requires_grad=True)
# Parameter containing:
# tensor([0.5586], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5584], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
# Parameter containing:
# tensor([0.5585], requires_grad=True)
#  91   | 0.1474  | 0.0905  | 0.4636  |  0 hr 13 min
# fold | epoch | train_MSE | valid MSE
#   4   |  38   | 0.0622  | 0.3773

# %%
# # evaluate model
# best_model = torch.load('saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(best_param["valid_epoch"])+'.pt')     

# best_model_dict = best_model.state_dict()
# best_model_wts = copy.deepcopy(best_model_dict)

# model.load_state_dict(best_model_wts)
# (best_model.align[0].weight == model.align[0].weight).all()
# test_MAE, test_MSE = eval(model, test_df)
# print("best epoch:",best_param["test_epoch"],"\n","test MSE:",test_MSE)

# %%
# for e in range(20):
#     losses = train(smiles_list[valid_fold[fold_index]])
#     print(losses)
