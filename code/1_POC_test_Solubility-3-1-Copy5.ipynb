# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

import time
import numpy as np
import gc
import sys
sys.setrecursionlimit(50000)
import pickle
import random
torch.set_default_tensor_type('torch.cuda.FloatTensor')
torch.nn.Module.dump_patches = True
import copy
import pandas as pd
from sklearn.model_selection import KFold

#then import my own modules
# from AttentiveFP import Fingerprint, Fingerprint_viz, save_smiles_dicts, get_smiles_dicts, get_smiles_array, moltosvg_highlight
from timeit import default_timer as timer
from AttentiveFP import Fingerprint, Fingerprint_viz, graph_dict, graph_dataset, null_collate, Graph, Logger, time_to_str

# %%
cuda_aviable = torch.cuda.is_available()
device = torch.device(0)

SEED = 8
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True
torch.backends.cudnn.deterministic=True

# %%
from rdkit import Chem
# from rdkit.Chem import AllChem
from rdkit.Chem import QED
from rdkit.Chem import rdMolDescriptors, MolSurf
from rdkit.Chem.Draw import SimilarityMaps
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
# %matplotlib inline
from numpy.polynomial.polynomial import polyfit
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib
import seaborn as sns; sns.set()
from IPython.display import SVG, display
import sascorer

# %%
task_name = 'solubility'
tasks = ['measured log solubility in mols per litre']

raw_filename = "../data/delaney-processed.csv"
feature_filename = raw_filename.replace('.csv','.pickle')
filename = raw_filename.replace('.csv','')
prefix_filename = raw_filename.split('/')[-1].replace('.csv','')
smiles_tasks_df = pd.read_csv(raw_filename)
smilesList = smiles_tasks_df.smiles.values
print("number of all smiles: ", len(smilesList))
atom_num_dist = []
remained_smiles = []
canonical_smiles_list = []
for smiles in smilesList:
    try:        
        mol = Chem.MolFromSmiles(smiles)
        atom_num_dist.append(len(mol.GetAtoms()))
        remained_smiles.append(smiles)
        canonical_smiles_list.append(Chem.MolToSmiles(Chem.MolFromSmiles(smiles), isomericSmiles=True))
    except:
        print(smiles)
        pass
print("number of successfully processed smiles: ", len(remained_smiles))

smiles_tasks_df = smiles_tasks_df[smiles_tasks_df["smiles"].isin(remained_smiles)].reset_index()
smiles_tasks_df['cano_smiles'] =canonical_smiles_list
plt.figure(figsize=(5, 3))
sns.set(font_scale=1.5)
ax = sns.distplot(atom_num_dist, bins=28, kde=False)
plt.tight_layout()
plt.show()
plt.close()
# Out:
# number of all smiles:  1128
# number of successfully processed smiles:  1128

# %%
start_time = str(time.ctime()).replace(':','-').replace(' ','_')

epochs = 80
batch_size =100

p_dropout= 0.2
fingerprint_dim = 50

weight_decay = 5 # also known as l2_regularization_lambda
learning_rate = 2.5
K = 2
T = 2
per_task_output_units_num = 1 # for regression model
output_units_num = len(tasks) * per_task_output_units_num

# %%
smiles_list = smiles_tasks_df['smiles'].values
label_list = smiles_tasks_df[tasks[0]].values
graph_dict = graph_dict(smiles_list, label_list, filename)
# Out:
# graph dicts loaded from ../data/delaney-processed.pkl

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
train_fold = []
valid_fold = []
for k, (train_idx, valid_idx) in enumerate(kfold.split(smiles_list)):
    train_fold.append(train_idx)
    valid_fold.append(valid_idx)
    
# avoiding the last batch has too few samples by slightly tune the batch_size
while (len(train_fold[0]) % batch_size) / batch_size <0.8:
    batch_size +=1
print("batch size: ", batch_size)
# Out:
# batch size:  101

# %%
loss_function = nn.MSELoss()
model = Fingerprint(output_units_num, fingerprint_dim, K=K, T=T, p_dropout=p_dropout)
model.to(device)

# optimizer = optim.Adam(model.parameters(), learning_rate, weight_decay=weight_decay)
optimizer = optim.Adam(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)
# optimizer = optim.SGD(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)

# model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in  model.parameters()])
print(params)
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data.shape)
# Out:
# 166954
# sum_importance torch.Size([1])
# preprocess.0.linear.weight torch.Size([50, 39])
# preprocess.0.linear.bias torch.Size([50])
# preprocess.0.bn.weight torch.Size([50])
# preprocess.0.bn.bias torch.Size([50])
# propagate.0.encoder.0.linear.weight torch.Size([2500, 10])
# propagate.0.encoder.0.linear.bias torch.Size([2500])
# propagate.0.encoder.0.bn.weight torch.Size([2500])
# propagate.0.encoder.0.bn.bias torch.Size([2500])
# propagate.0.align.weight torch.Size([1, 100])
# propagate.0.align.bias torch.Size([1])
# propagate.0.attend.linear.weight torch.Size([50, 50])
# propagate.0.attend.linear.bias torch.Size([50])
# propagate.0.attend.bn.weight torch.Size([50])
# propagate.0.attend.bn.bias torch.Size([50])
# propagate.0.gru.weight_ih torch.Size([150, 50])
# propagate.0.gru.weight_hh torch.Size([150, 50])
# propagate.0.gru.bias_ih torch.Size([150])
# propagate.0.gru.bias_hh torch.Size([150])
# propagate.1.encoder.0.linear.weight torch.Size([2500, 10])
# propagate.1.encoder.0.linear.bias torch.Size([2500])
# propagate.1.encoder.0.bn.weight torch.Size([2500])
# propagate.1.encoder.0.bn.bias torch.Size([2500])
# propagate.1.align.weight torch.Size([1, 100])
# propagate.1.align.bias torch.Size([1])
# propagate.1.attend.linear.weight torch.Size([50, 50])
# propagate.1.attend.linear.bias torch.Size([50])
# propagate.1.attend.bn.weight torch.Size([50])
# propagate.1.attend.bn.bias torch.Size([50])
# propagate.1.gru.weight_ih torch.Size([150, 50])
# propagate.1.gru.weight_hh torch.Size([150, 50])
# propagate.1.gru.bias_ih torch.Size([150])
# propagate.1.gru.bias_hh torch.Size([150])
# superGather.0.align.weight torch.Size([1, 100])
# superGather.0.align.bias torch.Size([1])
# superGather.0.attend.linear.weight torch.Size([50, 50])
# superGather.0.attend.linear.bias torch.Size([50])
# superGather.0.attend.bn.weight torch.Size([50])
# superGather.0.attend.bn.bias torch.Size([50])
# superGather.0.gru.weight_ih torch.Size([150, 50])
# superGather.0.gru.weight_hh torch.Size([150, 50])
# superGather.0.gru.bias_ih torch.Size([150])
# superGather.0.gru.bias_hh torch.Size([150])
# superGather.1.align.weight torch.Size([1, 100])
# superGather.1.align.bias torch.Size([1])
# superGather.1.attend.linear.weight torch.Size([50, 50])
# superGather.1.attend.linear.bias torch.Size([50])
# superGather.1.attend.bn.weight torch.Size([50])
# superGather.1.attend.bn.bias torch.Size([50])
# superGather.1.gru.weight_ih torch.Size([150, 50])
# superGather.1.gru.weight_hh torch.Size([150, 50])
# superGather.1.gru.bias_ih torch.Size([150])
# superGather.1.gru.bias_hh torch.Size([150])
# predict.0.linear.weight torch.Size([512, 50])
# predict.0.linear.bias torch.Size([512])
# predict.0.bn.weight torch.Size([512])
# predict.0.bn.bias torch.Size([512])
# predict.3.weight torch.Size([1, 512])
# predict.3.bias torch.Size([1])

# %%
def train(smiles_list):
    model.train()
    train_loader = DataLoader(graph_dataset(smiles_list, graph_dict), batch_size, collate_fn=null_collate, \
                              num_workers=8, pin_memory=True, shuffle=True, worker_init_fn=np.random.seed(SEED))
    losses = []
    for b, (smiles, atom, bond, bond_index, mol_index, label) in enumerate(train_loader):
        atom = atom.to(device)
        bond = bond.to(device)
        bond_index = bond_index.to(device)
        mol_index = mol_index.to(device)
        label = label.to(device)
        
        mol_prediction = model(atom, bond, bond_index, mol_index)
        
        loss = loss_function(mol_prediction, label.view(-1,1))     
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        losses.append(loss.item())

    return np.mean(losses)

        
def eval(smiles_list):
    model.eval()
    eval_MAE_list = []
    eval_MSE_list = []
    eval_loader = DataLoader(graph_dataset(smiles_list, graph_dict), batch_size, collate_fn=null_collate, \
                              num_workers=8, pin_memory=True, shuffle=False, worker_init_fn=np.random.seed(SEED))
    for b, (smiles, atom, bond, bond_index, mol_index, label) in enumerate(eval_loader):
        atom = atom.to(device)
        bond = bond.to(device)
        bond_index = bond_index.to(device)
        mol_index = mol_index.to(device)
        label = label.to(device)
        
        mol_prediction = model(atom, bond, bond_index, mol_index)
        MAE = F.l1_loss(mol_prediction, label.view(-1,1), reduction='none')        
        MSE = F.mse_loss(mol_prediction, label.view(-1,1), reduction='none')
        
        eval_MAE_list.extend(MAE.data.squeeze().cpu().numpy())
        eval_MSE_list.extend(MSE.data.squeeze().cpu().numpy())
    return np.array(eval_MAE_list).mean(), np.array(eval_MSE_list).mean()

# %%
# log = Logger()
# log.open(f'{prefix_filename}_{start_time}.txt')

# f = '{:^5} | {:^7.4f} | {:^7.4f} | {:^7.4f} | {:^7} \n'
# log.write('epoch | loss | train MSE |  valid MSE |  time \n')
# start = timer()

# best_param ={}
# best_param["train_epoch"] = 0
# best_param["valid_epoch"] = 0
# best_param["train_MSE"] = 9e8
# best_param["valid_MSE"] = 9e8

# fold_index = 3
# for epoch in range(800):
#     losses = train(smiles_list[train_fold[fold_index]])
#     traine_MAE, train_MSE = eval(smiles_list[train_fold[fold_index]])
#     valid_MAE, valid_MSE = eval(smiles_list[valid_fold[fold_index]])

#     timing = time_to_str((timer() - start), 'min')  
#     log.write(f.format(epoch, losses, train_MSE, valid_MSE, timing))

#     if train_MSE < best_param["train_MSE"]:
#         best_param["train_epoch"] = epoch
#         best_param["train_MSE"] = train_MSE
#     if valid_MSE < best_param["valid_MSE"]:
#         best_param["valid_epoch"] = epoch
#         best_param["valid_MSE"] = valid_MSE
# #         if valid_MSE < 0.35:
# #              torch.save(model, 'saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(epoch)+'.pt')
#     if (epoch - best_param["train_epoch"] >10) and (epoch - best_param["valid_epoch"] >18):        
#         break
# print(best_param["valid_epoch"],best_param["train_MSE"],best_param["valid_MSE"])

# %%
log = Logger()
log.open(f'log/{prefix_filename}_{start_time}.txt')

f = '{:^5} | {:^7.4f} | {:^7.4f} | {:^7.4f} | {:^7} \n'
log.write('epoch | loss | train MSE |  valid MSE |  time \n')
start = timer()

log2 = Logger()
log2.open(f'{prefix_filename}_best_{start_time}.txt')
f2 = '{:^5} | {:^5} | {:^7.4f} | {:^7.4f} \n'

for fold_index in range(5):
    
    model = Fingerprint(output_units_num, fingerprint_dim, K=K, T=T, p_dropout=p_dropout)
    model.to(device)

    optimizer = optim.Adam(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)
    
    best_param ={}
    best_param["train_epoch"] = 0
    best_param["valid_epoch"] = 0
    best_param["train_MSE"] = 800
    best_param["valid_MSE"] = 800
    for epoch in range(800):
        losses = train(smiles_list[train_fold[fold_index]])
        traine_MAE, train_MSE = eval(smiles_list[train_fold[fold_index]])
        valid_MAE, valid_MSE = eval(smiles_list[valid_fold[fold_index]])
        
        timing = time_to_str((timer() - start), 'min')  
        log.write(f.format(epoch, losses, train_MSE, valid_MSE, timing))
        
        if train_MSE < best_param["train_MSE"]:
            best_param["train_epoch"] = epoch
            best_param["train_MSE"] = train_MSE
        if valid_MSE < best_param["valid_MSE"]:
            best_param["valid_epoch"] = epoch
            best_param["valid_MSE"] = valid_MSE
#             if valid_MSE < 0.35:
#                  torch.save(model, 'saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(epoch)+'.pt')
        if (epoch - best_param["train_epoch"] >10) and (epoch - best_param["valid_epoch"] >18):        
            break

    log2.write('fold | epoch | train_MSE | valid MSE \n')
    log2.write(f2.format(fold_index, best_param["valid_epoch"],best_param["train_MSE"],best_param["valid_MSE"]))
# Out:
# epoch | loss | train MSE |  valid MSE |  time
# Parameter containing:
# tensor([0.6007], requires_grad=True)
# Parameter containing:
# tensor([0.6039], requires_grad=True)
# Parameter containing:
# tensor([0.6066], requires_grad=True)
# Parameter containing:
# tensor([0.6066], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6049], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6035], requires_grad=True)
# Parameter containing:
# tensor([0.6039], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6047], requires_grad=True)
#   0   | 5.8537  | 2.6201  | 3.0661  |  0 hr 00 min
# Parameter containing:
# tensor([0.6047], requires_grad=True)
# Parameter containing:
# tensor([0.6059], requires_grad=True)
# Parameter containing:
# tensor([0.6073], requires_grad=True)
# Parameter containing:
# tensor([0.6091], requires_grad=True)
# Parameter containing:
# tensor([0.6107], requires_grad=True)
# Parameter containing:
# tensor([0.6112], requires_grad=True)
# Parameter containing:
# tensor([0.6118], requires_grad=True)
# Parameter containing:
# tensor([0.6128], requires_grad=True)
# Parameter containing:
# tensor([0.6137], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6139], requires_grad=True)
#   1   | 1.8779  | 17.9775 | 19.3772 |  0 hr 00 min
# Parameter containing:
# tensor([0.6139], requires_grad=True)
# Parameter containing:
# tensor([0.6136], requires_grad=True)
# Parameter containing:
# tensor([0.6126], requires_grad=True)
# Parameter containing:
# tensor([0.6118], requires_grad=True)
# Parameter containing:
# tensor([0.6113], requires_grad=True)
# Parameter containing:
# tensor([0.6108], requires_grad=True)
# Parameter containing:
# tensor([0.6104], requires_grad=True)
# Parameter containing:
# tensor([0.6094], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
#   2   | 1.2093  | 8.3763  | 9.0395  |  0 hr 00 min
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6050], requires_grad=True)
# Parameter containing:
# tensor([0.6033], requires_grad=True)
# Parameter containing:
# tensor([0.6019], requires_grad=True)
# Parameter containing:
# tensor([0.6002], requires_grad=True)
# Parameter containing:
# tensor([0.5989], requires_grad=True)
# Parameter containing:
# tensor([0.5974], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5961], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5953], requires_grad=True)
#   3   | 0.9051  | 6.2935  | 6.8608  |  0 hr 00 min
# Parameter containing:
# tensor([0.5953], requires_grad=True)
# Parameter containing:
# tensor([0.5945], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5925], requires_grad=True)
# Parameter containing:
# tensor([0.5920], requires_grad=True)
# Parameter containing:
# tensor([0.5914], requires_grad=True)
# Parameter containing:
# tensor([0.5907], requires_grad=True)
# Parameter containing:
# tensor([0.5903], requires_grad=True)
# Parameter containing:
# tensor([0.5902], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
#   4   | 0.6192  | 1.6921  | 1.7836  |  0 hr 00 min
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5898], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5892], requires_grad=True)
# Parameter containing:
# tensor([0.5887], requires_grad=True)
# Parameter containing:
# tensor([0.5880], requires_grad=True)
# Parameter containing:
# tensor([0.5873], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
#   5   | 0.6640  | 0.5700  | 0.5986  |  0 hr 00 min
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5851], requires_grad=True)
# Parameter containing:
# tensor([0.5842], requires_grad=True)
# Parameter containing:
# tensor([0.5835], requires_grad=True)
# Parameter containing:
# tensor([0.5827], requires_grad=True)
# Parameter containing:
# tensor([0.5823], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5824], requires_grad=True)
# Parameter containing:
# tensor([0.5829], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5831], requires_grad=True)
#   6   | 0.6329  | 0.5137  | 0.5804  |  0 hr 00 min
# Parameter containing:
# tensor([0.5831], requires_grad=True)
# Parameter containing:
# tensor([0.5835], requires_grad=True)
# Parameter containing:
# tensor([0.5842], requires_grad=True)
# Parameter containing:
# tensor([0.5847], requires_grad=True)
# Parameter containing:
# tensor([0.5849], requires_grad=True)
# Parameter containing:
# tensor([0.5846], requires_grad=True)
# Parameter containing:
# tensor([0.5839], requires_grad=True)
# Parameter containing:
# tensor([0.5835], requires_grad=True)
# Parameter containing:
# tensor([0.5830], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
#   7   | 0.6250  | 0.3466  | 0.4280  |  0 hr 00 min
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5820], requires_grad=True)
# Parameter containing:
# tensor([0.5816], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5816], requires_grad=True)
# Parameter containing:
# tensor([0.5818], requires_grad=True)
# Parameter containing:
# tensor([0.5820], requires_grad=True)
# Parameter containing:
# tensor([0.5821], requires_grad=True)
# Parameter containing:
# tensor([0.5820], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5814], requires_grad=True)
#   8   | 0.4636  | 0.3681  | 0.4893  |  0 hr 00 min
# Parameter containing:
# tensor([0.5814], requires_grad=True)
# Parameter containing:
# tensor([0.5807], requires_grad=True)
# Parameter containing:
# tensor([0.5801], requires_grad=True)
# Parameter containing:
# tensor([0.5795], requires_grad=True)
# Parameter containing:
# tensor([0.5788], requires_grad=True)
# Parameter containing:
# tensor([0.5789], requires_grad=True)
# Parameter containing:
# tensor([0.5790], requires_grad=True)
# Parameter containing:
# tensor([0.5792], requires_grad=True)
# Parameter containing:
# tensor([0.5797], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5799], requires_grad=True)
#   9   | 0.4427  | 0.3481  | 0.4990  |  0 hr 00 min
# Parameter containing:
# tensor([0.5799], requires_grad=True)
# Parameter containing:
# tensor([0.5804], requires_grad=True)
# Parameter containing:
# tensor([0.5807], requires_grad=True)
# Parameter containing:
# tensor([0.5811], requires_grad=True)
# Parameter containing:
# tensor([0.5817], requires_grad=True)
# Parameter containing:
# tensor([0.5821], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5820], requires_grad=True)
# Parameter containing:
# tensor([0.5818], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5819], requires_grad=True)
#  10   | 0.3948  | 0.2845  | 0.4146  |  0 hr 00 min
# Parameter containing:
# tensor([0.5819], requires_grad=True)
# Parameter containing:
# tensor([0.5821], requires_grad=True)
# Parameter containing:
# tensor([0.5824], requires_grad=True)
# Parameter containing:
# tensor([0.5825], requires_grad=True)
# Parameter containing:
# tensor([0.5826], requires_grad=True)
# Parameter containing:
# tensor([0.5828], requires_grad=True)
# Parameter containing:
# tensor([0.5829], requires_grad=True)
# Parameter containing:
# tensor([0.5826], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
#  11   | 0.3888  | 0.2585  | 0.3865  |  0 hr 00 min
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5821], requires_grad=True)
# Parameter containing:
# tensor([0.5818], requires_grad=True)
# Parameter containing:
# tensor([0.5813], requires_grad=True)
# Parameter containing:
# tensor([0.5808], requires_grad=True)
# Parameter containing:
# tensor([0.5807], requires_grad=True)
# Parameter containing:
# tensor([0.5808], requires_grad=True)
# Parameter containing:
# tensor([0.5813], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5822], requires_grad=True)
#  12   | 0.4392  | 0.2521  | 0.3867  |  0 hr 00 min
# Parameter containing:
# tensor([0.5822], requires_grad=True)
# Parameter containing:
# tensor([0.5828], requires_grad=True)
# Parameter containing:
# tensor([0.5835], requires_grad=True)
# Parameter containing:
# tensor([0.5844], requires_grad=True)
# Parameter containing:
# tensor([0.5849], requires_grad=True)
# Parameter containing:
# tensor([0.5857], requires_grad=True)
# Parameter containing:
# tensor([0.5864], requires_grad=True)
# Parameter containing:
# tensor([0.5870], requires_grad=True)
# Parameter containing:
# tensor([0.5874], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
#  13   | 0.3950  | 0.3305  | 0.4207  |  0 hr 00 min
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5876], requires_grad=True)
# Parameter containing:
# tensor([0.5871], requires_grad=True)
# Parameter containing:
# tensor([0.5867], requires_grad=True)
# Parameter containing:
# tensor([0.5863], requires_grad=True)
# Parameter containing:
# tensor([0.5856], requires_grad=True)
# Parameter containing:
# tensor([0.5853], requires_grad=True)
# Parameter containing:
# tensor([0.5857], requires_grad=True)
# Parameter containing:
# tensor([0.5861], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5866], requires_grad=True)
#  14   | 0.3948  | 0.2163  | 0.3835  |  0 hr 00 min
# Parameter containing:
# tensor([0.5866], requires_grad=True)
# Parameter containing:
# tensor([0.5870], requires_grad=True)
# Parameter containing:
# tensor([0.5876], requires_grad=True)
# Parameter containing:
# tensor([0.5880], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5885], requires_grad=True)
# Parameter containing:
# tensor([0.5886], requires_grad=True)
# Parameter containing:
# tensor([0.5886], requires_grad=True)
# Parameter containing:
# tensor([0.5887], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
#  15   | 0.3542  | 0.2218  | 0.3883  |  0 hr 00 min
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5879], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5874], requires_grad=True)
# Parameter containing:
# tensor([0.5875], requires_grad=True)
# Parameter containing:
# tensor([0.5875], requires_grad=True)
# Parameter containing:
# tensor([0.5877], requires_grad=True)
# Parameter containing:
# tensor([0.5875], requires_grad=True)
# Parameter containing:
# tensor([0.5878], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5883], requires_grad=True)
#  16   | 0.3899  | 0.3624  | 0.5902  |  0 hr 00 min
# Parameter containing:
# tensor([0.5883], requires_grad=True)
# Parameter containing:
# tensor([0.5885], requires_grad=True)
# Parameter containing:
# tensor([0.5886], requires_grad=True)
# Parameter containing:
# tensor([0.5887], requires_grad=True)
# Parameter containing:
# tensor([0.5890], requires_grad=True)
# Parameter containing:
# tensor([0.5891], requires_grad=True)
# Parameter containing:
# tensor([0.5892], requires_grad=True)
# Parameter containing:
# tensor([0.5892], requires_grad=True)
# Parameter containing:
# tensor([0.5894], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
#  17   | 0.3840  | 0.3311  | 0.4413  |  0 hr 00 min
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5902], requires_grad=True)
# Parameter containing:
# tensor([0.5909], requires_grad=True)
# Parameter containing:
# tensor([0.5912], requires_grad=True)
# Parameter containing:
# tensor([0.5911], requires_grad=True)
# Parameter containing:
# tensor([0.5906], requires_grad=True)
# Parameter containing:
# tensor([0.5899], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5894], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5896], requires_grad=True)
#  18   | 0.4000  | 0.2037  | 0.3861  |  0 hr 00 min
# Parameter containing:
# tensor([0.5896], requires_grad=True)
# Parameter containing:
# tensor([0.5900], requires_grad=True)
# Parameter containing:
# tensor([0.5903], requires_grad=True)
# Parameter containing:
# tensor([0.5908], requires_grad=True)
# Parameter containing:
# tensor([0.5911], requires_grad=True)
# Parameter containing:
# tensor([0.5915], requires_grad=True)
# Parameter containing:
# tensor([0.5919], requires_grad=True)
# Parameter containing:
# tensor([0.5922], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
#  19   | 0.2800  | 0.1881  | 0.3514  |  0 hr 00 min
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5924], requires_grad=True)
# Parameter containing:
# tensor([0.5925], requires_grad=True)
# Parameter containing:
# tensor([0.5925], requires_grad=True)
# Parameter containing:
# tensor([0.5927], requires_grad=True)
# Parameter containing:
# tensor([0.5930], requires_grad=True)
# Parameter containing:
# tensor([0.5932], requires_grad=True)
# Parameter containing:
# tensor([0.5939], requires_grad=True)
# Parameter containing:
# tensor([0.5945], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5946], requires_grad=True)
#  20   | 0.3877  | 0.1986  | 0.3849  |  0 hr 00 min
# Parameter containing:
# tensor([0.5946], requires_grad=True)
# Parameter containing:
# tensor([0.5945], requires_grad=True)
# Parameter containing:
# tensor([0.5943], requires_grad=True)
# Parameter containing:
# tensor([0.5939], requires_grad=True)
# Parameter containing:
# tensor([0.5937], requires_grad=True)
# Parameter containing:
# tensor([0.5937], requires_grad=True)
# Parameter containing:
# tensor([0.5937], requires_grad=True)
# Parameter containing:
# tensor([0.5937], requires_grad=True)
# Parameter containing:
# tensor([0.5938], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5940], requires_grad=True)
#  21   | 0.3835  | 0.2121  | 0.3575  |  0 hr 00 min
# Parameter containing:
# tensor([0.5940], requires_grad=True)
# Parameter containing:
# tensor([0.5945], requires_grad=True)
# Parameter containing:
# tensor([0.5950], requires_grad=True)
# Parameter containing:
# tensor([0.5947], requires_grad=True)
# Parameter containing:
# tensor([0.5943], requires_grad=True)
# Parameter containing:
# tensor([0.5937], requires_grad=True)
# Parameter containing:
# tensor([0.5937], requires_grad=True)
# Parameter containing:
# tensor([0.5935], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5936], requires_grad=True)
#  22   | 0.3210  | 0.2061  | 0.3916  |  0 hr 00 min
# Parameter containing:
# tensor([0.5936], requires_grad=True)
# Parameter containing:
# tensor([0.5934], requires_grad=True)
# Parameter containing:
# tensor([0.5939], requires_grad=True)
# Parameter containing:
# tensor([0.5947], requires_grad=True)
# Parameter containing:
# tensor([0.5955], requires_grad=True)
# Parameter containing:
# tensor([0.5961], requires_grad=True)
# Parameter containing:
# tensor([0.5963], requires_grad=True)
# Parameter containing:
# tensor([0.5962], requires_grad=True)
# Parameter containing:
# tensor([0.5963], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5967], requires_grad=True)
#  23   | 0.3158  | 0.2062  | 0.3467  |  0 hr 00 min
# Parameter containing:
# tensor([0.5967], requires_grad=True)
# Parameter containing:
# tensor([0.5971], requires_grad=True)
# Parameter containing:
# tensor([0.5979], requires_grad=True)
# Parameter containing:
# tensor([0.5987], requires_grad=True)
# Parameter containing:
# tensor([0.5994], requires_grad=True)
# Parameter containing:
# tensor([0.6002], requires_grad=True)
# Parameter containing:
# tensor([0.6010], requires_grad=True)
# Parameter containing:
# tensor([0.6015], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
#  24   | 0.3292  | 0.2065  | 0.3553  |  0 hr 01 min
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6025], requires_grad=True)
# Parameter containing:
# tensor([0.6024], requires_grad=True)
# Parameter containing:
# tensor([0.6025], requires_grad=True)
# Parameter containing:
# tensor([0.6024], requires_grad=True)
# Parameter containing:
# tensor([0.6022], requires_grad=True)
# Parameter containing:
# tensor([0.6021], requires_grad=True)
# Parameter containing:
# tensor([0.6015], requires_grad=True)
# Parameter containing:
# tensor([0.6009], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6006], requires_grad=True)
#  25   | 0.3376  | 0.1621  | 0.3555  |  0 hr 01 min
# Parameter containing:
# tensor([0.6006], requires_grad=True)
# Parameter containing:
# tensor([0.6005], requires_grad=True)
# Parameter containing:
# tensor([0.6003], requires_grad=True)
# Parameter containing:
# tensor([0.6007], requires_grad=True)
# Parameter containing:
# tensor([0.6010], requires_grad=True)
# Parameter containing:
# tensor([0.6012], requires_grad=True)
# Parameter containing:
# tensor([0.6014], requires_grad=True)
# Parameter containing:
# tensor([0.6015], requires_grad=True)
# Parameter containing:
# tensor([0.6018], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6020], requires_grad=True)
#  26   | 0.3063  | 0.1991  | 0.3887  |  0 hr 01 min
# Parameter containing:
# tensor([0.6020], requires_grad=True)
# Parameter containing:
# tensor([0.6028], requires_grad=True)
# Parameter containing:
# tensor([0.6034], requires_grad=True)
# Parameter containing:
# tensor([0.6036], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6040], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6035], requires_grad=True)
# Parameter containing:
# tensor([0.6031], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6027], requires_grad=True)
#  27   | 0.3313  | 0.1946  | 0.4348  |  0 hr 01 min
# Parameter containing:
# tensor([0.6027], requires_grad=True)
# Parameter containing:
# tensor([0.6023], requires_grad=True)
# Parameter containing:
# tensor([0.6024], requires_grad=True)
# Parameter containing:
# tensor([0.6031], requires_grad=True)
# Parameter containing:
# tensor([0.6033], requires_grad=True)
# Parameter containing:
# tensor([0.6039], requires_grad=True)
# Parameter containing:
# tensor([0.6043], requires_grad=True)
# Parameter containing:
# tensor([0.6048], requires_grad=True)
# Parameter containing:
# tensor([0.6059], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
#  28   | 0.3606  | 0.2335  | 0.4446  |  0 hr 01 min
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6070], requires_grad=True)
# Parameter containing:
# tensor([0.6072], requires_grad=True)
# Parameter containing:
# tensor([0.6068], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6061], requires_grad=True)
# Parameter containing:
# tensor([0.6058], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6046], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6038], requires_grad=True)
#  29   | 0.3649  | 0.2148  | 0.3732  |  0 hr 01 min
# Parameter containing:
# tensor([0.6038], requires_grad=True)
# Parameter containing:
# tensor([0.6032], requires_grad=True)
# Parameter containing:
# tensor([0.6032], requires_grad=True)
# Parameter containing:
# tensor([0.6036], requires_grad=True)
# Parameter containing:
# tensor([0.6042], requires_grad=True)
# Parameter containing:
# tensor([0.6049], requires_grad=True)
# Parameter containing:
# tensor([0.6053], requires_grad=True)
# Parameter containing:
# tensor([0.6053], requires_grad=True)
# Parameter containing:
# tensor([0.6053], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
#  30   | 0.2967  | 0.2542  | 0.4812  |  0 hr 01 min
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6052], requires_grad=True)
# Parameter containing:
# tensor([0.6051], requires_grad=True)
# Parameter containing:
# tensor([0.6050], requires_grad=True)
# Parameter containing:
# tensor([0.6050], requires_grad=True)
# Parameter containing:
# tensor([0.6053], requires_grad=True)
# Parameter containing:
# tensor([0.6055], requires_grad=True)
# Parameter containing:
# tensor([0.6056], requires_grad=True)
# Parameter containing:
# tensor([0.6060], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6063], requires_grad=True)
#  31   | 0.2835  | 0.2035  | 0.4513  |  0 hr 01 min
# Parameter containing:
# tensor([0.6063], requires_grad=True)
# Parameter containing:
# tensor([0.6067], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6084], requires_grad=True)
# Parameter containing:
# tensor([0.6090], requires_grad=True)
# Parameter containing:
# tensor([0.6093], requires_grad=True)
# Parameter containing:
# tensor([0.6092], requires_grad=True)
# Parameter containing:
# tensor([0.6085], requires_grad=True)
# Parameter containing:
# tensor([0.6080], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
#  32   | 0.2496  | 0.1378  | 0.3332  |  0 hr 01 min
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6073], requires_grad=True)
# Parameter containing:
# tensor([0.6070], requires_grad=True)
# Parameter containing:
# tensor([0.6068], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6064], requires_grad=True)
# Parameter containing:
# tensor([0.6070], requires_grad=True)
# Parameter containing:
# tensor([0.6073], requires_grad=True)
# Parameter containing:
# tensor([0.6074], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
#  33   | 0.3401  | 0.1589  | 0.3936  |  0 hr 01 min
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6078], requires_grad=True)
# Parameter containing:
# tensor([0.6078], requires_grad=True)
# Parameter containing:
# tensor([0.6076], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6072], requires_grad=True)
# Parameter containing:
# tensor([0.6072], requires_grad=True)
# Parameter containing:
# tensor([0.6070], requires_grad=True)
# Parameter containing:
# tensor([0.6070], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
#  34   | 0.3055  | 0.1530  | 0.3491  |  0 hr 01 min
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6069], requires_grad=True)
# Parameter containing:
# tensor([0.6068], requires_grad=True)
# Parameter containing:
# tensor([0.6066], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6065], requires_grad=True)
# Parameter containing:
# tensor([0.6066], requires_grad=True)
# Parameter containing:
# tensor([0.6072], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
#  35   | 0.2700  | 0.1512  | 0.3529  |  0 hr 01 min
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6087], requires_grad=True)
# Parameter containing:
# tensor([0.6083], requires_grad=True)
# Parameter containing:
# tensor([0.6077], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6074], requires_grad=True)
# Parameter containing:
# tensor([0.6075], requires_grad=True)
# Parameter containing:
# tensor([0.6076], requires_grad=True)
# Parameter containing:
# tensor([0.6078], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
#  36   | 0.2714  | 0.1296  | 0.3526  |  0 hr 01 min
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# Parameter containing:
# tensor([0.6079], requires_grad=True)
# ...
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
#  94   | 0.1762  | 0.0837  | 0.3412  |  0 hr 18 min
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2904], requires_grad=True)
# Parameter containing:
# tensor([0.2904], requires_grad=True)
# Parameter containing:
# tensor([0.2904], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2902], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
#  95   | 0.1827  | 0.0714  | 0.3881  |  0 hr 18 min
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2900], requires_grad=True)
# Parameter containing:
# tensor([0.2899], requires_grad=True)
# Parameter containing:
# tensor([0.2897], requires_grad=True)
# Parameter containing:
# tensor([0.2896], requires_grad=True)
# Parameter containing:
# tensor([0.2895], requires_grad=True)
# Parameter containing:
# tensor([0.2895], requires_grad=True)
# Parameter containing:
# tensor([0.2896], requires_grad=True)
# Parameter containing:
# tensor([0.2895], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2894], requires_grad=True)
#  96   | 0.1462  | 0.0926  | 0.3713  |  0 hr 18 min
# Parameter containing:
# tensor([0.2894], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2893], requires_grad=True)
# Parameter containing:
# tensor([0.2893], requires_grad=True)
# Parameter containing:
# tensor([0.2891], requires_grad=True)
# Parameter containing:
# tensor([0.2889], requires_grad=True)
# Parameter containing:
# tensor([0.2887], requires_grad=True)
# Parameter containing:
# tensor([0.2889], requires_grad=True)
# Parameter containing:
# tensor([0.2890], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2892], requires_grad=True)
#  97   | 0.1841  | 0.0986  | 0.4206  |  0 hr 18 min
# Parameter containing:
# tensor([0.2892], requires_grad=True)
# Parameter containing:
# tensor([0.2895], requires_grad=True)
# Parameter containing:
# tensor([0.2899], requires_grad=True)
# Parameter containing:
# tensor([0.2903], requires_grad=True)
# Parameter containing:
# tensor([0.2908], requires_grad=True)
# Parameter containing:
# tensor([0.2912], requires_grad=True)
# Parameter containing:
# tensor([0.2913], requires_grad=True)
# Parameter containing:
# tensor([0.2915], requires_grad=True)
# Parameter containing:
# tensor([0.2917], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2919], requires_grad=True)
#  98   | 0.2121  | 0.0716  | 0.3886  |  0 hr 18 min
# Parameter containing:
# tensor([0.2919], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2922], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2929], requires_grad=True)
# Parameter containing:
# tensor([0.2933], requires_grad=True)
# Parameter containing:
# tensor([0.2934], requires_grad=True)
# Parameter containing:
# tensor([0.2931], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
#  99   | 0.1496  | 0.0986  | 0.3766  |  0 hr 18 min
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2917], requires_grad=True)
# Parameter containing:
# tensor([0.2913], requires_grad=True)
# Parameter containing:
# tensor([0.2908], requires_grad=True)
# Parameter containing:
# tensor([0.2905], requires_grad=True)
# Parameter containing:
# tensor([0.2902], requires_grad=True)
# Parameter containing:
# tensor([0.2900], requires_grad=True)
# Parameter containing:
# tensor([0.2899], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
#  100  | 0.1779  | 0.0973  | 0.3872  |  0 hr 18 min
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2904], requires_grad=True)
# Parameter containing:
# tensor([0.2905], requires_grad=True)
# Parameter containing:
# tensor([0.2904], requires_grad=True)
# Parameter containing:
# tensor([0.2902], requires_grad=True)
# Parameter containing:
# tensor([0.2898], requires_grad=True)
# Parameter containing:
# tensor([0.2897], requires_grad=True)
# Parameter containing:
# tensor([0.2897], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2901], requires_grad=True)
#  101  | 0.2020  | 0.0861  | 0.3996  |  0 hr 18 min
# Parameter containing:
# tensor([0.2901], requires_grad=True)
# Parameter containing:
# tensor([0.2909], requires_grad=True)
# Parameter containing:
# tensor([0.2917], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2935], requires_grad=True)
# Parameter containing:
# tensor([0.2942], requires_grad=True)
# Parameter containing:
# tensor([0.2945], requires_grad=True)
# Parameter containing:
# tensor([0.2946], requires_grad=True)
# Parameter containing:
# tensor([0.2944], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2940], requires_grad=True)
#  102  | 0.1510  | 0.0736  | 0.3547  |  0 hr 18 min
# Parameter containing:
# tensor([0.2940], requires_grad=True)
# Parameter containing:
# tensor([0.2936], requires_grad=True)
# Parameter containing:
# tensor([0.2931], requires_grad=True)
# Parameter containing:
# tensor([0.2925], requires_grad=True)
# Parameter containing:
# tensor([0.2921], requires_grad=True)
# Parameter containing:
# tensor([0.2918], requires_grad=True)
# Parameter containing:
# tensor([0.2916], requires_grad=True)
# Parameter containing:
# tensor([0.2915], requires_grad=True)
# Parameter containing:
# tensor([0.2912], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
#  103  | 0.2256  | 0.1056  | 0.3590  |  0 hr 18 min
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2908], requires_grad=True)
# Parameter containing:
# tensor([0.2908], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2910], requires_grad=True)
# Parameter containing:
# tensor([0.2913], requires_grad=True)
# Parameter containing:
# tensor([0.2916], requires_grad=True)
# Parameter containing:
# tensor([0.2918], requires_grad=True)
# Parameter containing:
# tensor([0.2921], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2926], requires_grad=True)
#  104  | 0.1517  | 0.0825  | 0.4324  |  0 hr 18 min
# Parameter containing:
# tensor([0.2926], requires_grad=True)
# Parameter containing:
# tensor([0.2931], requires_grad=True)
# Parameter containing:
# tensor([0.2935], requires_grad=True)
# Parameter containing:
# tensor([0.2938], requires_grad=True)
# Parameter containing:
# tensor([0.2942], requires_grad=True)
# Parameter containing:
# tensor([0.2944], requires_grad=True)
# Parameter containing:
# tensor([0.2942], requires_grad=True)
# Parameter containing:
# tensor([0.2937], requires_grad=True)
# Parameter containing:
# tensor([0.2931], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2927], requires_grad=True)
#  105  | 0.1690  | 0.1175  | 0.4922  |  0 hr 18 min
# Parameter containing:
# tensor([0.2927], requires_grad=True)
# Parameter containing:
# tensor([0.2924], requires_grad=True)
# Parameter containing:
# tensor([0.2921], requires_grad=True)
# Parameter containing:
# tensor([0.2918], requires_grad=True)
# Parameter containing:
# tensor([0.2916], requires_grad=True)
# Parameter containing:
# tensor([0.2915], requires_grad=True)
# Parameter containing:
# tensor([0.2914], requires_grad=True)
# Parameter containing:
# tensor([0.2916], requires_grad=True)
# Parameter containing:
# tensor([0.2917], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
# Parameter containing:
# tensor([0.2920], requires_grad=True)
#  106  | 0.2125  | 0.1978  | 0.4935  |  0 hr 18 min
# fold | epoch | train_MSE | valid MSE
#   4   |  74   | 0.0714  | 0.3288

# %%
# # evaluate model
# best_model = torch.load('saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(best_param["valid_epoch"])+'.pt')     

# best_model_dict = best_model.state_dict()
# best_model_wts = copy.deepcopy(best_model_dict)

# model.load_state_dict(best_model_wts)
# (best_model.align[0].weight == model.align[0].weight).all()
# test_MAE, test_MSE = eval(model, test_df)
# print("best epoch:",best_param["test_epoch"],"\n","test MSE:",test_MSE)

# %%
# for e in range(20):
#     losses = train(smiles_list[valid_fold[fold_index]])
#     print(losses)
