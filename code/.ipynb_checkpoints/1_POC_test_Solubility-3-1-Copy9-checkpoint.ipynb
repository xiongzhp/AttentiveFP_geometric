# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

import time
import numpy as np
import gc
import sys
sys.setrecursionlimit(50000)
import pickle
import random
torch.set_default_tensor_type('torch.cuda.FloatTensor')
torch.nn.Module.dump_patches = True
import copy
import pandas as pd
from sklearn.model_selection import KFold

#then import my own modules
# from AttentiveFP import Fingerprint, Fingerprint_viz, save_smiles_dicts, get_smiles_dicts, get_smiles_array, moltosvg_highlight
from timeit import default_timer as timer
from AttentiveFP import Fingerprint, Fingerprint_viz, graph_dict, graph_dataset, null_collate, Graph, Logger, time_to_str

# %%
cuda_aviable = torch.cuda.is_available()
device = torch.device(0)

SEED = 8
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True
torch.backends.cudnn.deterministic=True

# %%
from rdkit import Chem
# from rdkit.Chem import AllChem
from rdkit.Chem import QED
from rdkit.Chem import rdMolDescriptors, MolSurf
from rdkit.Chem.Draw import SimilarityMaps
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
# %matplotlib inline
from numpy.polynomial.polynomial import polyfit
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib
import seaborn as sns; sns.set()
from IPython.display import SVG, display
import sascorer

# %%
task_name = 'solubility'
tasks = ['measured log solubility in mols per litre']

raw_filename = "../data/delaney-processed.csv"
feature_filename = raw_filename.replace('.csv','.pickle')
filename = raw_filename.replace('.csv','')
prefix_filename = raw_filename.split('/')[-1].replace('.csv','')
smiles_tasks_df = pd.read_csv(raw_filename)
smilesList = smiles_tasks_df.smiles.values
print("number of all smiles: ", len(smilesList))
atom_num_dist = []
remained_smiles = []
canonical_smiles_list = []
for smiles in smilesList:
    try:        
        mol = Chem.MolFromSmiles(smiles)
        atom_num_dist.append(len(mol.GetAtoms()))
        remained_smiles.append(smiles)
        canonical_smiles_list.append(Chem.MolToSmiles(Chem.MolFromSmiles(smiles), isomericSmiles=True))
    except:
        print(smiles)
        pass
print("number of successfully processed smiles: ", len(remained_smiles))

smiles_tasks_df = smiles_tasks_df[smiles_tasks_df["smiles"].isin(remained_smiles)].reset_index()
smiles_tasks_df['cano_smiles'] =canonical_smiles_list
plt.figure(figsize=(5, 3))
sns.set(font_scale=1.5)
ax = sns.distplot(atom_num_dist, bins=28, kde=False)
plt.tight_layout()
plt.show()
plt.close()
# Out:
# number of all smiles:  1128
# number of successfully processed smiles:  1128

# %%
start_time = str(time.ctime()).replace(':','-').replace(' ','_')

epochs = 80
batch_size =100

p_dropout= 0.2
fingerprint_dim = 50

weight_decay = 5 # also known as l2_regularization_lambda
learning_rate = 3
K = 2
T = 2
per_task_output_units_num = 1 # for regression model
output_units_num = len(tasks) * per_task_output_units_num

# %%
smiles_list = smiles_tasks_df['smiles'].values
label_list = smiles_tasks_df[tasks[0]].values
graph_dict = graph_dict(smiles_list, label_list, filename)
# Out:
# graph dicts loaded from ../data/delaney-processed.pkl

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
train_fold = []
valid_fold = []
for k, (train_idx, valid_idx) in enumerate(kfold.split(smiles_list)):
    train_fold.append(train_idx)
    valid_fold.append(valid_idx)
    
# avoiding the last batch has too few samples by slightly tune the batch_size
while (len(train_fold[0]) % batch_size) / batch_size <0.8:
    batch_size +=1
print("batch size: ", batch_size)
# Out:
# batch size:  101

# %%
loss_function = nn.MSELoss()
model = Fingerprint(output_units_num, fingerprint_dim, K=K, T=T, p_dropout=p_dropout)
model.to(device)

# optimizer = optim.Adam(model.parameters(), learning_rate, weight_decay=weight_decay)
optimizer = optim.Adam(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)
# optimizer = optim.SGD(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)

# model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in  model.parameters()])
print(params)
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.data.shape)
# Out:
# 166954
# sum_importance torch.Size([1])
# preprocess.0.linear.weight torch.Size([50, 39])
# preprocess.0.linear.bias torch.Size([50])
# preprocess.0.bn.weight torch.Size([50])
# preprocess.0.bn.bias torch.Size([50])
# propagate.0.encoder.0.linear.weight torch.Size([2500, 10])
# propagate.0.encoder.0.linear.bias torch.Size([2500])
# propagate.0.encoder.0.bn.weight torch.Size([2500])
# propagate.0.encoder.0.bn.bias torch.Size([2500])
# propagate.0.align.weight torch.Size([1, 100])
# propagate.0.align.bias torch.Size([1])
# propagate.0.attend.linear.weight torch.Size([50, 50])
# propagate.0.attend.linear.bias torch.Size([50])
# propagate.0.attend.bn.weight torch.Size([50])
# propagate.0.attend.bn.bias torch.Size([50])
# propagate.0.gru.weight_ih torch.Size([150, 50])
# propagate.0.gru.weight_hh torch.Size([150, 50])
# propagate.0.gru.bias_ih torch.Size([150])
# propagate.0.gru.bias_hh torch.Size([150])
# propagate.1.encoder.0.linear.weight torch.Size([2500, 10])
# propagate.1.encoder.0.linear.bias torch.Size([2500])
# propagate.1.encoder.0.bn.weight torch.Size([2500])
# propagate.1.encoder.0.bn.bias torch.Size([2500])
# propagate.1.align.weight torch.Size([1, 100])
# propagate.1.align.bias torch.Size([1])
# propagate.1.attend.linear.weight torch.Size([50, 50])
# propagate.1.attend.linear.bias torch.Size([50])
# propagate.1.attend.bn.weight torch.Size([50])
# propagate.1.attend.bn.bias torch.Size([50])
# propagate.1.gru.weight_ih torch.Size([150, 50])
# propagate.1.gru.weight_hh torch.Size([150, 50])
# propagate.1.gru.bias_ih torch.Size([150])
# propagate.1.gru.bias_hh torch.Size([150])
# superGather.0.align.weight torch.Size([1, 100])
# superGather.0.align.bias torch.Size([1])
# superGather.0.attend.linear.weight torch.Size([50, 50])
# superGather.0.attend.linear.bias torch.Size([50])
# superGather.0.attend.bn.weight torch.Size([50])
# superGather.0.attend.bn.bias torch.Size([50])
# superGather.0.gru.weight_ih torch.Size([150, 50])
# superGather.0.gru.weight_hh torch.Size([150, 50])
# superGather.0.gru.bias_ih torch.Size([150])
# superGather.0.gru.bias_hh torch.Size([150])
# superGather.1.align.weight torch.Size([1, 100])
# superGather.1.align.bias torch.Size([1])
# superGather.1.attend.linear.weight torch.Size([50, 50])
# superGather.1.attend.linear.bias torch.Size([50])
# superGather.1.attend.bn.weight torch.Size([50])
# superGather.1.attend.bn.bias torch.Size([50])
# superGather.1.gru.weight_ih torch.Size([150, 50])
# superGather.1.gru.weight_hh torch.Size([150, 50])
# superGather.1.gru.bias_ih torch.Size([150])
# superGather.1.gru.bias_hh torch.Size([150])
# predict.0.linear.weight torch.Size([512, 50])
# predict.0.linear.bias torch.Size([512])
# predict.0.bn.weight torch.Size([512])
# predict.0.bn.bias torch.Size([512])
# predict.3.weight torch.Size([1, 512])
# predict.3.bias torch.Size([1])

# %%
def train(smiles_list):
    model.train()
    train_loader = DataLoader(graph_dataset(smiles_list, graph_dict), batch_size, collate_fn=null_collate, \
                              num_workers=8, pin_memory=True, shuffle=True, worker_init_fn=np.random.seed(SEED))
    losses = []
    for b, (smiles, atom, bond, bond_index, mol_index, label) in enumerate(train_loader):
        atom = atom.to(device)
        bond = bond.to(device)
        bond_index = bond_index.to(device)
        mol_index = mol_index.to(device)
        label = label.to(device)
        
        mol_prediction = model(atom, bond, bond_index, mol_index)
        
        loss = loss_function(mol_prediction, label.view(-1,1))     
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        losses.append(loss.item())

    return np.mean(losses)

        
def eval(smiles_list):
    model.eval()
    eval_MAE_list = []
    eval_MSE_list = []
    eval_loader = DataLoader(graph_dataset(smiles_list, graph_dict), batch_size, collate_fn=null_collate, \
                              num_workers=8, pin_memory=True, shuffle=False, worker_init_fn=np.random.seed(SEED))
    for b, (smiles, atom, bond, bond_index, mol_index, label) in enumerate(eval_loader):
        atom = atom.to(device)
        bond = bond.to(device)
        bond_index = bond_index.to(device)
        mol_index = mol_index.to(device)
        label = label.to(device)
        
        mol_prediction = model(atom, bond, bond_index, mol_index)
        MAE = F.l1_loss(mol_prediction, label.view(-1,1), reduction='none')        
        MSE = F.mse_loss(mol_prediction, label.view(-1,1), reduction='none')
        
        eval_MAE_list.extend(MAE.data.squeeze().cpu().numpy())
        eval_MSE_list.extend(MSE.data.squeeze().cpu().numpy())
    return np.array(eval_MAE_list).mean(), np.array(eval_MSE_list).mean()

# %%
# log = Logger()
# log.open(f'{prefix_filename}_{start_time}.txt')

# f = '{:^5} | {:^7.4f} | {:^7.4f} | {:^7.4f} | {:^7} \n'
# log.write('epoch | loss | train MSE |  valid MSE |  time \n')
# start = timer()

# best_param ={}
# best_param["train_epoch"] = 0
# best_param["valid_epoch"] = 0
# best_param["train_MSE"] = 9e8
# best_param["valid_MSE"] = 9e8

# fold_index = 3
# for epoch in range(800):
#     losses = train(smiles_list[train_fold[fold_index]])
#     traine_MAE, train_MSE = eval(smiles_list[train_fold[fold_index]])
#     valid_MAE, valid_MSE = eval(smiles_list[valid_fold[fold_index]])

#     timing = time_to_str((timer() - start), 'min')  
#     log.write(f.format(epoch, losses, train_MSE, valid_MSE, timing))

#     if train_MSE < best_param["train_MSE"]:
#         best_param["train_epoch"] = epoch
#         best_param["train_MSE"] = train_MSE
#     if valid_MSE < best_param["valid_MSE"]:
#         best_param["valid_epoch"] = epoch
#         best_param["valid_MSE"] = valid_MSE
# #         if valid_MSE < 0.35:
# #              torch.save(model, 'saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(epoch)+'.pt')
#     if (epoch - best_param["train_epoch"] >10) and (epoch - best_param["valid_epoch"] >18):        
#         break
# print(best_param["valid_epoch"],best_param["train_MSE"],best_param["valid_MSE"])

# %%
log = Logger()
log.open(f'log/{prefix_filename}_{start_time}.txt')

f = '{:^5} | {:^7.4f} | {:^7.4f} | {:^7.4f} | {:^7} \n'
log.write('epoch | loss | train MSE |  valid MSE |  time \n')
start = timer()

log2 = Logger()
log2.open(f'{prefix_filename}_best_{start_time}.txt')
f2 = '{:^5} | {:^5} | {:^7.4f} | {:^7.4f} \n'

for fold_index in range(5):
    
    model = Fingerprint(output_units_num, fingerprint_dim, K=K, T=T, p_dropout=p_dropout)
    model.to(device)

    optimizer = optim.Adam(model.parameters(), 10**-learning_rate, weight_decay=10**-weight_decay)
    
    best_param ={}
    best_param["train_epoch"] = 0
    best_param["valid_epoch"] = 0
    best_param["train_MSE"] = 800
    best_param["valid_MSE"] = 800
    for epoch in range(800):
        losses = train(smiles_list[train_fold[fold_index]])
        traine_MAE, train_MSE = eval(smiles_list[train_fold[fold_index]])
        valid_MAE, valid_MSE = eval(smiles_list[valid_fold[fold_index]])
        
        timing = time_to_str((timer() - start), 'min')  
        log.write(f.format(epoch, losses, train_MSE, valid_MSE, timing))
        
        if train_MSE < best_param["train_MSE"]:
            best_param["train_epoch"] = epoch
            best_param["train_MSE"] = train_MSE
        if valid_MSE < best_param["valid_MSE"]:
            best_param["valid_epoch"] = epoch
            best_param["valid_MSE"] = valid_MSE
#             if valid_MSE < 0.35:
#                  torch.save(model, 'saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(epoch)+'.pt')
        if (epoch - best_param["train_epoch"] >10) and (epoch - best_param["valid_epoch"] >18):        
            break

    log2.write('fold | epoch | train_MSE | valid MSE \n')
    log2.write(f2.format(fold_index, best_param["valid_epoch"],best_param["train_MSE"],best_param["valid_MSE"]))
# Out:
# epoch | loss | train MSE |  valid MSE |  time
# tensor([0.5000], grad_fn=<SigmoidBackward>)
# tensor([0.4998], grad_fn=<SigmoidBackward>)
# tensor([0.4995], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4991], grad_fn=<SigmoidBackward>)
# tensor([0.4991], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
#   0   | 9.4977  | 11.0098 | 11.1090 |  0 hr 00 min
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4991], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4994], grad_fn=<SigmoidBackward>)
# tensor([0.4995], grad_fn=<SigmoidBackward>)
# tensor([0.4995], grad_fn=<SigmoidBackward>)
# tensor([0.4994], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
#   1   | 3.9524  | 4.5433  | 4.9740  |  0 hr 00 min
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4991], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4989], grad_fn=<SigmoidBackward>)
# tensor([0.4988], grad_fn=<SigmoidBackward>)
# tensor([0.4988], grad_fn=<SigmoidBackward>)
# tensor([0.4988], grad_fn=<SigmoidBackward>)
# tensor([0.4988], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
#   2   | 1.8020  | 2.3639  | 3.0817  |  0 hr 00 min
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4986], grad_fn=<SigmoidBackward>)
# tensor([0.4986], grad_fn=<SigmoidBackward>)
# tensor([0.4986], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4985], grad_fn=<SigmoidBackward>)
#   3   | 1.2413  | 1.8055  | 2.4446  |  0 hr 00 min
# tensor([0.4985], grad_fn=<SigmoidBackward>)
# tensor([0.4986], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4987], grad_fn=<SigmoidBackward>)
# tensor([0.4988], grad_fn=<SigmoidBackward>)
# tensor([0.4989], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4990], grad_fn=<SigmoidBackward>)
# tensor([0.4991], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4992], grad_fn=<SigmoidBackward>)
#   4   | 1.0176  | 1.4107  | 1.7080  |  0 hr 00 min
# tensor([0.4992], grad_fn=<SigmoidBackward>)
# tensor([0.4993], grad_fn=<SigmoidBackward>)
# tensor([0.4994], grad_fn=<SigmoidBackward>)
# tensor([0.4994], grad_fn=<SigmoidBackward>)
# tensor([0.4995], grad_fn=<SigmoidBackward>)
# tensor([0.4996], grad_fn=<SigmoidBackward>)
# tensor([0.4996], grad_fn=<SigmoidBackward>)
# tensor([0.4997], grad_fn=<SigmoidBackward>)
# tensor([0.4998], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.4999], grad_fn=<SigmoidBackward>)
#   5   | 0.7917  | 0.6775  | 0.7388  |  0 hr 00 min
# tensor([0.4999], grad_fn=<SigmoidBackward>)
# tensor([0.5001], grad_fn=<SigmoidBackward>)
# tensor([0.5002], grad_fn=<SigmoidBackward>)
# tensor([0.5003], grad_fn=<SigmoidBackward>)
# tensor([0.5004], grad_fn=<SigmoidBackward>)
# tensor([0.5005], grad_fn=<SigmoidBackward>)
# tensor([0.5006], grad_fn=<SigmoidBackward>)
# tensor([0.5007], grad_fn=<SigmoidBackward>)
# tensor([0.5009], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5010], grad_fn=<SigmoidBackward>)
#   6   | 0.7372  | 0.5898  | 0.6320  |  0 hr 00 min
# tensor([0.5010], grad_fn=<SigmoidBackward>)
# tensor([0.5011], grad_fn=<SigmoidBackward>)
# tensor([0.5012], grad_fn=<SigmoidBackward>)
# tensor([0.5013], grad_fn=<SigmoidBackward>)
# tensor([0.5014], grad_fn=<SigmoidBackward>)
# tensor([0.5015], grad_fn=<SigmoidBackward>)
# tensor([0.5015], grad_fn=<SigmoidBackward>)
# tensor([0.5016], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5017], grad_fn=<SigmoidBackward>)
#   7   | 0.6689  | 0.4746  | 0.5886  |  0 hr 00 min
# tensor([0.5017], grad_fn=<SigmoidBackward>)
# tensor([0.5018], grad_fn=<SigmoidBackward>)
# tensor([0.5018], grad_fn=<SigmoidBackward>)
# tensor([0.5019], grad_fn=<SigmoidBackward>)
# tensor([0.5020], grad_fn=<SigmoidBackward>)
# tensor([0.5021], grad_fn=<SigmoidBackward>)
# tensor([0.5021], grad_fn=<SigmoidBackward>)
# tensor([0.5021], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
#   8   | 0.5441  | 0.3763  | 0.4909  |  0 hr 00 min
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5022], grad_fn=<SigmoidBackward>)
# tensor([0.5023], grad_fn=<SigmoidBackward>)
# tensor([0.5023], grad_fn=<SigmoidBackward>)
# tensor([0.5024], grad_fn=<SigmoidBackward>)
# tensor([0.5024], grad_fn=<SigmoidBackward>)
# tensor([0.5025], grad_fn=<SigmoidBackward>)
# tensor([0.5026], grad_fn=<SigmoidBackward>)
# tensor([0.5026], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5027], grad_fn=<SigmoidBackward>)
#   9   | 0.5052  | 0.3309  | 0.4313  |  0 hr 00 min
# tensor([0.5027], grad_fn=<SigmoidBackward>)
# tensor([0.5028], grad_fn=<SigmoidBackward>)
# tensor([0.5028], grad_fn=<SigmoidBackward>)
# tensor([0.5029], grad_fn=<SigmoidBackward>)
# tensor([0.5030], grad_fn=<SigmoidBackward>)
# tensor([0.5030], grad_fn=<SigmoidBackward>)
# tensor([0.5031], grad_fn=<SigmoidBackward>)
# tensor([0.5032], grad_fn=<SigmoidBackward>)
# tensor([0.5033], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5034], grad_fn=<SigmoidBackward>)
#  10   | 0.4867  | 0.3814  | 0.5208  |  0 hr 00 min
# tensor([0.5034], grad_fn=<SigmoidBackward>)
# tensor([0.5035], grad_fn=<SigmoidBackward>)
# tensor([0.5036], grad_fn=<SigmoidBackward>)
# tensor([0.5037], grad_fn=<SigmoidBackward>)
# tensor([0.5038], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
#  11   | 0.4894  | 0.3577  | 0.4861  |  0 hr 00 min
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5039], grad_fn=<SigmoidBackward>)
# tensor([0.5040], grad_fn=<SigmoidBackward>)
# tensor([0.5040], grad_fn=<SigmoidBackward>)
# tensor([0.5040], grad_fn=<SigmoidBackward>)
# tensor([0.5040], grad_fn=<SigmoidBackward>)
# tensor([0.5040], grad_fn=<SigmoidBackward>)
# tensor([0.5040], grad_fn=<SigmoidBackward>)
# tensor([0.5041], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5042], grad_fn=<SigmoidBackward>)
#  12   | 0.5582  | 0.2917  | 0.4075  |  0 hr 00 min
# tensor([0.5042], grad_fn=<SigmoidBackward>)
# tensor([0.5043], grad_fn=<SigmoidBackward>)
# tensor([0.5044], grad_fn=<SigmoidBackward>)
# tensor([0.5045], grad_fn=<SigmoidBackward>)
# tensor([0.5046], grad_fn=<SigmoidBackward>)
# tensor([0.5047], grad_fn=<SigmoidBackward>)
# tensor([0.5048], grad_fn=<SigmoidBackward>)
# tensor([0.5048], grad_fn=<SigmoidBackward>)
# tensor([0.5049], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
#  13   | 0.5180  | 0.4753  | 0.5771  |  0 hr 00 min
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5050], grad_fn=<SigmoidBackward>)
# tensor([0.5051], grad_fn=<SigmoidBackward>)
# tensor([0.5051], grad_fn=<SigmoidBackward>)
# tensor([0.5051], grad_fn=<SigmoidBackward>)
# tensor([0.5051], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
#  14   | 0.4813  | 0.3426  | 0.4753  |  0 hr 00 min
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5052], grad_fn=<SigmoidBackward>)
# tensor([0.5053], grad_fn=<SigmoidBackward>)
# tensor([0.5053], grad_fn=<SigmoidBackward>)
# tensor([0.5054], grad_fn=<SigmoidBackward>)
# tensor([0.5055], grad_fn=<SigmoidBackward>)
# tensor([0.5055], grad_fn=<SigmoidBackward>)
# tensor([0.5056], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
#  15   | 0.4090  | 0.2558  | 0.3942  |  0 hr 00 min
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5057], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
#  16   | 0.4425  | 0.2597  | 0.3998  |  0 hr 00 min
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5058], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5059], grad_fn=<SigmoidBackward>)
# tensor([0.5060], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5061], grad_fn=<SigmoidBackward>)
#  17   | 0.4025  | 0.2778  | 0.3927  |  0 hr 00 min
# tensor([0.5061], grad_fn=<SigmoidBackward>)
# tensor([0.5062], grad_fn=<SigmoidBackward>)
# tensor([0.5062], grad_fn=<SigmoidBackward>)
# tensor([0.5063], grad_fn=<SigmoidBackward>)
# tensor([0.5063], grad_fn=<SigmoidBackward>)
# tensor([0.5063], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5064], grad_fn=<SigmoidBackward>)
#  18   | 0.4553  | 0.2393  | 0.4007  |  0 hr 00 min
# tensor([0.5064], grad_fn=<SigmoidBackward>)
# tensor([0.5065], grad_fn=<SigmoidBackward>)
# tensor([0.5065], grad_fn=<SigmoidBackward>)
# tensor([0.5066], grad_fn=<SigmoidBackward>)
# tensor([0.5066], grad_fn=<SigmoidBackward>)
# tensor([0.5067], grad_fn=<SigmoidBackward>)
# tensor([0.5068], grad_fn=<SigmoidBackward>)
# tensor([0.5069], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5070], grad_fn=<SigmoidBackward>)
#  19   | 0.3669  | 0.2490  | 0.3821  |  0 hr 00 min
# tensor([0.5070], grad_fn=<SigmoidBackward>)
# tensor([0.5071], grad_fn=<SigmoidBackward>)
# tensor([0.5071], grad_fn=<SigmoidBackward>)
# tensor([0.5071], grad_fn=<SigmoidBackward>)
# tensor([0.5072], grad_fn=<SigmoidBackward>)
# tensor([0.5073], grad_fn=<SigmoidBackward>)
# tensor([0.5074], grad_fn=<SigmoidBackward>)
# tensor([0.5075], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
#  20   | 0.4266  | 0.2146  | 0.3653  |  0 hr 00 min
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5076], grad_fn=<SigmoidBackward>)
# tensor([0.5077], grad_fn=<SigmoidBackward>)
# tensor([0.5078], grad_fn=<SigmoidBackward>)
# tensor([0.5079], grad_fn=<SigmoidBackward>)
# tensor([0.5079], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
#  21   | 0.4251  | 0.2499  | 0.3775  |  0 hr 00 min
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5080], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
#  22   | 0.3595  | 0.2438  | 0.4116  |  0 hr 00 min
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5081], grad_fn=<SigmoidBackward>)
# tensor([0.5082], grad_fn=<SigmoidBackward>)
# tensor([0.5082], grad_fn=<SigmoidBackward>)
# tensor([0.5083], grad_fn=<SigmoidBackward>)
# tensor([0.5084], grad_fn=<SigmoidBackward>)
# tensor([0.5084], grad_fn=<SigmoidBackward>)
# tensor([0.5084], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5085], grad_fn=<SigmoidBackward>)
#  23   | 0.3732  | 0.2529  | 0.3686  |  0 hr 00 min
# tensor([0.5085], grad_fn=<SigmoidBackward>)
# tensor([0.5086], grad_fn=<SigmoidBackward>)
# tensor([0.5087], grad_fn=<SigmoidBackward>)
# tensor([0.5088], grad_fn=<SigmoidBackward>)
# tensor([0.5088], grad_fn=<SigmoidBackward>)
# tensor([0.5089], grad_fn=<SigmoidBackward>)
# tensor([0.5089], grad_fn=<SigmoidBackward>)
# tensor([0.5090], grad_fn=<SigmoidBackward>)
# tensor([0.5091], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5092], grad_fn=<SigmoidBackward>)
#  24   | 0.3977  | 0.2434  | 0.4485  |  0 hr 00 min
# tensor([0.5092], grad_fn=<SigmoidBackward>)
# tensor([0.5093], grad_fn=<SigmoidBackward>)
# tensor([0.5093], grad_fn=<SigmoidBackward>)
# tensor([0.5093], grad_fn=<SigmoidBackward>)
# tensor([0.5093], grad_fn=<SigmoidBackward>)
# tensor([0.5093], grad_fn=<SigmoidBackward>)
# tensor([0.5093], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
#  25   | 0.3994  | 0.2061  | 0.3596  |  0 hr 00 min
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5094], grad_fn=<SigmoidBackward>)
# tensor([0.5095], grad_fn=<SigmoidBackward>)
# tensor([0.5095], grad_fn=<SigmoidBackward>)
# tensor([0.5096], grad_fn=<SigmoidBackward>)
# tensor([0.5096], grad_fn=<SigmoidBackward>)
# tensor([0.5096], grad_fn=<SigmoidBackward>)
# tensor([0.5097], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
#  26   | 0.3333  | 0.2075  | 0.3770  |  0 hr 00 min
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5098], grad_fn=<SigmoidBackward>)
# tensor([0.5099], grad_fn=<SigmoidBackward>)
# tensor([0.5099], grad_fn=<SigmoidBackward>)
# tensor([0.5100], grad_fn=<SigmoidBackward>)
# tensor([0.5101], grad_fn=<SigmoidBackward>)
# tensor([0.5101], grad_fn=<SigmoidBackward>)
# tensor([0.5101], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
#  27   | 0.3206  | 0.2013  | 0.3859  |  0 hr 01 min
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5102], grad_fn=<SigmoidBackward>)
# tensor([0.5103], grad_fn=<SigmoidBackward>)
# tensor([0.5103], grad_fn=<SigmoidBackward>)
# tensor([0.5104], grad_fn=<SigmoidBackward>)
# tensor([0.5105], grad_fn=<SigmoidBackward>)
# tensor([0.5105], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5106], grad_fn=<SigmoidBackward>)
#  28   | 0.3202  | 0.1883  | 0.3907  |  0 hr 01 min
# tensor([0.5106], grad_fn=<SigmoidBackward>)
# tensor([0.5107], grad_fn=<SigmoidBackward>)
# tensor([0.5107], grad_fn=<SigmoidBackward>)
# tensor([0.5107], grad_fn=<SigmoidBackward>)
# tensor([0.5107], grad_fn=<SigmoidBackward>)
# tensor([0.5107], grad_fn=<SigmoidBackward>)
# tensor([0.5108], grad_fn=<SigmoidBackward>)
# tensor([0.5108], grad_fn=<SigmoidBackward>)
# tensor([0.5109], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
#  29   | 0.3765  | 0.2006  | 0.3845  |  0 hr 01 min
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5110], grad_fn=<SigmoidBackward>)
# tensor([0.5111], grad_fn=<SigmoidBackward>)
# tensor([0.5112], grad_fn=<SigmoidBackward>)
# tensor([0.5112], grad_fn=<SigmoidBackward>)
# tensor([0.5113], grad_fn=<SigmoidBackward>)
# tensor([0.5113], grad_fn=<SigmoidBackward>)
# tensor([0.5114], grad_fn=<SigmoidBackward>)
# tensor([0.5114], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5115], grad_fn=<SigmoidBackward>)
#  30   | 0.3242  | 0.3477  | 0.5152  |  0 hr 01 min
# tensor([0.5115], grad_fn=<SigmoidBackward>)
# tensor([0.5116], grad_fn=<SigmoidBackward>)
# tensor([0.5116], grad_fn=<SigmoidBackward>)
# tensor([0.5117], grad_fn=<SigmoidBackward>)
# tensor([0.5117], grad_fn=<SigmoidBackward>)
# tensor([0.5118], grad_fn=<SigmoidBackward>)
# tensor([0.5119], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
#  31   | 0.3055  | 0.2107  | 0.3710  |  0 hr 01 min
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5120], grad_fn=<SigmoidBackward>)
# tensor([0.5121], grad_fn=<SigmoidBackward>)
# tensor([0.5121], grad_fn=<SigmoidBackward>)
# tensor([0.5122], grad_fn=<SigmoidBackward>)
# tensor([0.5122], grad_fn=<SigmoidBackward>)
# tensor([0.5122], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5123], grad_fn=<SigmoidBackward>)
#  32   | 0.2960  | 0.2033  | 0.4247  |  0 hr 01 min
# tensor([0.5123], grad_fn=<SigmoidBackward>)
# tensor([0.5124], grad_fn=<SigmoidBackward>)
# tensor([0.5124], grad_fn=<SigmoidBackward>)
# tensor([0.5125], grad_fn=<SigmoidBackward>)
# tensor([0.5125], grad_fn=<SigmoidBackward>)
# tensor([0.5126], grad_fn=<SigmoidBackward>)
# tensor([0.5127], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
#  33   | 0.3786  | 0.2106  | 0.4255  |  0 hr 01 min
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5127], grad_fn=<SigmoidBackward>)
# tensor([0.5127], grad_fn=<SigmoidBackward>)
# tensor([0.5126], grad_fn=<SigmoidBackward>)
# tensor([0.5126], grad_fn=<SigmoidBackward>)
# tensor([0.5126], grad_fn=<SigmoidBackward>)
# tensor([0.5126], grad_fn=<SigmoidBackward>)
# tensor([0.5126], grad_fn=<SigmoidBackward>)
# tensor([0.5127], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
#  34   | 0.3381  | 0.1718  | 0.3960  |  0 hr 01 min
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5128], grad_fn=<SigmoidBackward>)
# tensor([0.5129], grad_fn=<SigmoidBackward>)
# tensor([0.5129], grad_fn=<SigmoidBackward>)
# tensor([0.5129], grad_fn=<SigmoidBackward>)
# tensor([0.5130], grad_fn=<SigmoidBackward>)
# tensor([0.5131], grad_fn=<SigmoidBackward>)
# tensor([0.5132], grad_fn=<SigmoidBackward>)
# tensor([0.5132], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
#  35   | 0.3026  | 0.1768  | 0.4122  |  0 hr 01 min
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5132], grad_fn=<SigmoidBackward>)
# tensor([0.5132], grad_fn=<SigmoidBackward>)
# tensor([0.5132], grad_fn=<SigmoidBackward>)
# tensor([0.5132], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
#  36   | 0.3017  | 0.1746  | 0.3749  |  0 hr 01 min
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5133], grad_fn=<SigmoidBackward>)
# tensor([0.5134], grad_fn=<SigmoidBackward>)
# tensor([0.5135], grad_fn=<SigmoidBackward>)
# tensor([0.5135], grad_fn=<SigmoidBackward>)
# tensor([0.5136], grad_fn=<SigmoidBackward>)
# tensor([0.5137], grad_fn=<SigmoidBackward>)
# tensor([0.5138], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
#  37   | 0.2832  | 0.1844  | 0.3976  |  0 hr 01 min
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5139], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
#  38   | 0.3477  | 0.1646  | 0.3728  |  0 hr 01 min
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5140], grad_fn=<SigmoidBackward>)
# tensor([0.5141], grad_fn=<SigmoidBackward>)
# tensor([0.5142], grad_fn=<SigmoidBackward>)
# tensor([0.5143], grad_fn=<SigmoidBackward>)
# tensor([0.5144], grad_fn=<SigmoidBackward>)
# tensor([0.5145], grad_fn=<SigmoidBackward>)
# tensor([0.5146], grad_fn=<SigmoidBackward>)
# tensor([0.5146], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
#  39   | 0.2722  | 0.1748  | 0.4090  |  0 hr 01 min
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5146], grad_fn=<SigmoidBackward>)
# tensor([0.5146], grad_fn=<SigmoidBackward>)
# tensor([0.5146], grad_fn=<SigmoidBackward>)
# tensor([0.5146], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
#  40   | 0.2795  | 0.1630  | 0.3595  |  0 hr 01 min
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5147], grad_fn=<SigmoidBackward>)
# tensor([0.5148], grad_fn=<SigmoidBackward>)
# tensor([0.5148], grad_fn=<SigmoidBackward>)
# tensor([0.5148], grad_fn=<SigmoidBackward>)
# tensor([0.5149], grad_fn=<SigmoidBackward>)
# tensor([0.5150], grad_fn=<SigmoidBackward>)
# tensor([0.5150], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5151], grad_fn=<SigmoidBackward>)
#  41   | 0.3243  | 0.1708  | 0.3911  |  0 hr 01 min
# tensor([0.5151], grad_fn=<SigmoidBackward>)
# tensor([0.5152], grad_fn=<SigmoidBackward>)
# tensor([0.5152], grad_fn=<SigmoidBackward>)
# tensor([0.5152], grad_fn=<SigmoidBackward>)
# tensor([0.5153], grad_fn=<SigmoidBackward>)
# tensor([0.5153], grad_fn=<SigmoidBackward>)
# tensor([0.5154], grad_fn=<SigmoidBackward>)
# tensor([0.5154], grad_fn=<SigmoidBackward>)
# tensor([0.5155], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
#  42   | 0.2952  | 0.1771  | 0.3829  |  0 hr 01 min
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5156], grad_fn=<SigmoidBackward>)
# tensor([0.5157], grad_fn=<SigmoidBackward>)
# tensor([0.5158], grad_fn=<SigmoidBackward>)
# tensor([0.5158], grad_fn=<SigmoidBackward>)
# tensor([0.5158], grad_fn=<SigmoidBackward>)
# tensor([0.5159], grad_fn=<SigmoidBackward>)
# tensor([0.5160], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
#  43   | 0.2939  | 0.1867  | 0.4021  |  0 hr 01 min
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5161], grad_fn=<SigmoidBackward>)
# tensor([0.5162], grad_fn=<SigmoidBackward>)
# tensor([0.5163], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5165], grad_fn=<SigmoidBackward>)
#  44   | 0.2795  | 0.1562  | 0.3645  |  0 hr 01 min
# tensor([0.5165], grad_fn=<SigmoidBackward>)
# tensor([0.5166], grad_fn=<SigmoidBackward>)
# tensor([0.5168], grad_fn=<SigmoidBackward>)
# tensor([0.5169], grad_fn=<SigmoidBackward>)
# tensor([0.5170], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
#  45   | 0.2971  | 0.1746  | 0.4209  |  0 hr 01 min
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
#  46   | 0.3453  | 0.1777  | 0.3702  |  0 hr 01 min
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5170], grad_fn=<SigmoidBackward>)
# tensor([0.5170], grad_fn=<SigmoidBackward>)
# tensor([0.5170], grad_fn=<SigmoidBackward>)
# tensor([0.5170], grad_fn=<SigmoidBackward>)
# tensor([0.5170], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
#  47   | 0.3177  | 0.2213  | 0.4763  |  0 hr 01 min
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5171], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5172], grad_fn=<SigmoidBackward>)
# tensor([0.5173], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
#  48   | 0.2576  | 0.1551  | 0.3761  |  0 hr 01 min
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# tensor([0.5174], grad_fn=<SigmoidBackward>)
# ...
# tensor([0.5246], grad_fn=<SigmoidBackward>)
# tensor([0.5246], grad_fn=<SigmoidBackward>)
# tensor([0.5246], grad_fn=<SigmoidBackward>)
# tensor([0.5246], grad_fn=<SigmoidBackward>)
# tensor([0.5246], grad_fn=<SigmoidBackward>)
#  69   | 0.2307  | 0.1100  | 0.3654  |  0 hr 23 min
# tensor([0.5246], grad_fn=<SigmoidBackward>)
# tensor([0.5247], grad_fn=<SigmoidBackward>)
# tensor([0.5247], grad_fn=<SigmoidBackward>)
# tensor([0.5248], grad_fn=<SigmoidBackward>)
# tensor([0.5248], grad_fn=<SigmoidBackward>)
# tensor([0.5249], grad_fn=<SigmoidBackward>)
# tensor([0.5250], grad_fn=<SigmoidBackward>)
# tensor([0.5250], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
#  70   | 0.2094  | 0.1022  | 0.3524  |  0 hr 23 min
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5251], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
#  71   | 0.2361  | 0.1156  | 0.3766  |  0 hr 23 min
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5252], grad_fn=<SigmoidBackward>)
# tensor([0.5253], grad_fn=<SigmoidBackward>)
# tensor([0.5254], grad_fn=<SigmoidBackward>)
# tensor([0.5256], grad_fn=<SigmoidBackward>)
# tensor([0.5257], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5259], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
#  72   | 0.2123  | 0.0982  | 0.3520  |  0 hr 23 min
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5258], grad_fn=<SigmoidBackward>)
# tensor([0.5259], grad_fn=<SigmoidBackward>)
# tensor([0.5259], grad_fn=<SigmoidBackward>)
# tensor([0.5260], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
#  73   | 0.2547  | 0.0975  | 0.3481  |  0 hr 23 min
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5260], grad_fn=<SigmoidBackward>)
# tensor([0.5260], grad_fn=<SigmoidBackward>)
# tensor([0.5260], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5261], grad_fn=<SigmoidBackward>)
#  74   | 0.2151  | 0.0951  | 0.3558  |  0 hr 23 min
# tensor([0.5261], grad_fn=<SigmoidBackward>)
# tensor([0.5262], grad_fn=<SigmoidBackward>)
# tensor([0.5263], grad_fn=<SigmoidBackward>)
# tensor([0.5264], grad_fn=<SigmoidBackward>)
# tensor([0.5265], grad_fn=<SigmoidBackward>)
# tensor([0.5266], grad_fn=<SigmoidBackward>)
# tensor([0.5266], grad_fn=<SigmoidBackward>)
# tensor([0.5267], grad_fn=<SigmoidBackward>)
# tensor([0.5267], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
#  75   | 0.1778  | 0.1128  | 0.3982  |  0 hr 23 min
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5268], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
#  76   | 0.2291  | 0.1158  | 0.3790  |  0 hr 23 min
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5269], grad_fn=<SigmoidBackward>)
# tensor([0.5270], grad_fn=<SigmoidBackward>)
# tensor([0.5270], grad_fn=<SigmoidBackward>)
# tensor([0.5270], grad_fn=<SigmoidBackward>)
# tensor([0.5270], grad_fn=<SigmoidBackward>)
# tensor([0.5270], grad_fn=<SigmoidBackward>)
# tensor([0.5271], grad_fn=<SigmoidBackward>)
# tensor([0.5271], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5272], grad_fn=<SigmoidBackward>)
#  77   | 0.1942  | 0.1222  | 0.4176  |  0 hr 23 min
# tensor([0.5272], grad_fn=<SigmoidBackward>)
# tensor([0.5273], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5276], grad_fn=<SigmoidBackward>)
# tensor([0.5276], grad_fn=<SigmoidBackward>)
# tensor([0.5276], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
#  78   | 0.2023  | 0.1066  | 0.3715  |  0 hr 23 min
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5274], grad_fn=<SigmoidBackward>)
#  79   | 0.1830  | 0.1148  | 0.3856  |  0 hr 23 min
# tensor([0.5274], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5275], grad_fn=<SigmoidBackward>)
# tensor([0.5276], grad_fn=<SigmoidBackward>)
# tensor([0.5277], grad_fn=<SigmoidBackward>)
# tensor([0.5278], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
#  80   | 0.2234  | 0.0998  | 0.3637  |  0 hr 23 min
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
#  81   | 0.1973  | 0.1041  | 0.3511  |  0 hr 23 min
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
#  82   | 0.2204  | 0.1395  | 0.4630  |  0 hr 23 min
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5279], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5280], grad_fn=<SigmoidBackward>)
# tensor([0.5281], grad_fn=<SigmoidBackward>)
# tensor([0.5281], grad_fn=<SigmoidBackward>)
# tensor([0.5282], grad_fn=<SigmoidBackward>)
# tensor([0.5282], grad_fn=<SigmoidBackward>)
# tensor([0.5283], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
#  83   | 0.2092  | 0.1008  | 0.3805  |  0 hr 23 min
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5284], grad_fn=<SigmoidBackward>)
# tensor([0.5285], grad_fn=<SigmoidBackward>)
# tensor([0.5285], grad_fn=<SigmoidBackward>)
# tensor([0.5286], grad_fn=<SigmoidBackward>)
# tensor([0.5287], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5288], grad_fn=<SigmoidBackward>)
#  84   | 0.2065  | 0.1100  | 0.3935  |  0 hr 24 min
# tensor([0.5288], grad_fn=<SigmoidBackward>)
# tensor([0.5289], grad_fn=<SigmoidBackward>)
# tensor([0.5289], grad_fn=<SigmoidBackward>)
# tensor([0.5290], grad_fn=<SigmoidBackward>)
# tensor([0.5290], grad_fn=<SigmoidBackward>)
# tensor([0.5291], grad_fn=<SigmoidBackward>)
# tensor([0.5291], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
# tensor([0.5292], grad_fn=<SigmoidBackward>)
#  85   | 0.1935  | 0.0994  | 0.3817  |  0 hr 24 min
# fold | epoch | train_MSE | valid MSE
#   4   |  57   | 0.0951  | 0.3327

# %%
# # evaluate model
# best_model = torch.load('saved_models/model_'+prefix_filename+'_'+start_time+'_'+str(best_param["valid_epoch"])+'.pt')     

# best_model_dict = best_model.state_dict()
# best_model_wts = copy.deepcopy(best_model_dict)

# model.load_state_dict(best_model_wts)
# (best_model.align[0].weight == model.align[0].weight).all()
# test_MAE, test_MSE = eval(model, test_df)
# print("best epoch:",best_param["test_epoch"],"\n","test MSE:",test_MSE)

# %%
# for e in range(20):
#     losses = train(smiles_list[valid_fold[fold_index]])
#     print(losses)
